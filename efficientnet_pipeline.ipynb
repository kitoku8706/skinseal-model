# %%
# GPU 상태 및 PyTorch 버전 확인
import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA Device Count: {torch.cuda.device_count()}")
    print(f"Current CUDA Device: {torch.cuda.current_device()}")
    print(f"CUDA Device Name: {torch.cuda.get_device_name(0)}")
    print(f"CUDA Version: {torch.version.cuda}")
else:
    print("⚠️ CUDA is not available!")
    print("가능한 원인:")
    print("1. PyTorch가 CPU 전용으로 설치됨")
    print("2. NVIDIA 드라이버 문제")
    print("3. CUDA 런타임 문제")
    print("\n해결 방법:")
    print("pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118")
# Out:
# PyTorch Version: 2.7.1+cu118
# CUDA Available: True
# CUDA Device Count: 1
# Current CUDA Device: 0
# CUDA Device Name: NVIDIA GeForce RTX 4070 Ti SUPER
# CUDA Version: 11.8

# %% [markdown]
# # EfficientNet-B0 피부질환 분류 전체 파이프라인
# 이 노트북은 EfficientNet-B0을 이용한 피부질환 이미지 분류의 데이터 준비, 학습, 검증, 평가, 시각화까지의 전체 과정을 담고 있습니다.

# %%
# 1. 라이브러리 임포트 및 환경 설정 (수정)
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets, models  # models 추가
from torch.utils.data import DataLoader
# from efficientnet_pytorch import EfficientNet  # 주석 처리
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# 2. 데이터 경로 및 하이퍼파라미터 + 결과 저장 폴더 생성
from datetime import datetime
DATA_DIR = './'  # 데이터셋 폴더 위치
IMAGE_SIZE = 224
BATCH_SIZE = 32  # 원래 배치 크기

# 날짜/시간별 결과 저장 폴더 생성
now_str = datetime.now().strftime('%Y%m%d_%H%M%S')
results_dir = os.path.join('results', now_str)
os.makedirs(results_dir, exist_ok=True)
print(f'결과 저장 폴더: {results_dir}')
# Out:
# 결과 저장 폴더: results\20251021_145847

# %%
# 3. 데이터 전처리 및 데이터로더 (최소 설정)
train_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485]*3, [0.229]*3),
])
val_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485]*3, [0.229]*3),
])
train_ds = datasets.ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_ds   = datasets.ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_transform)
# 데이터가 너무 많을 경우 일부만 샘플링해서 사용하려면 아래 주석 해제
# from torch.utils.data import Subset
# train_ds = Subset(train_ds, range(0, min(10, len(train_ds))))
# val_ds = Subset(val_ds, range(0, min(10, len(val_ds))))
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
class_names = train_ds.classes if hasattr(train_ds, 'classes') else train_ds.dataset.classes
print(f'클래스 목록: {class_names}')
# Out:
# 클래스 목록: ['Acne', 'Actinic_Keratosis', 'Benign_tumors', 'Bullous', 'Candidiasis', 'DrugEruption', 'Eczema', 'Infestations_Bites', 'Lichen', 'Lupus', 'Moles', 'Psoriasis', 'Rosacea', 'Seborrh_Keratoses', 'SkinCancer', 'Sun_Sunlight_Damage', 'Tinea', 'Unknown_Normal', 'Vascular_Tumors', 'Vasculitis', 'Vitiligo', 'Warts']

# %%
# 4. 클래스 불균형 보정 (가중치 계산)
labels = [label for _, label in train_ds.samples]
classes = np.arange(len(train_ds.classes))
class_weights = compute_class_weight('balanced', classes=classes, y=labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
print('Class weights:', class_weights)
# Out:
# Class weights: tensor([1.0653, 0.8446, 0.5780, 1.2534, 2.5473, 1.1549, 0.6255, 1.2056, 1.1424,
#         2.0313, 1.7499, 0.7704, 2.4871, 1.3884, 0.9116, 2.0248, 0.6844, 0.3826,
#         1.1634, 1.3703, 0.8848, 1.0892], device='cuda:0')

# %%
# 5. EfficientNet-B0 모델 생성 및 학습 준비 (수정)
# torchvision 사용 버전 (경고 무시)
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

model = models.efficientnet_b0(pretrained=True)  # 경고는 무시하고 기존 방식 사용
model.classifier[1] = nn.Linear(model.classifier[1].in_features, len(train_ds.classes))
model.to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.AdamW(model.parameters(), lr=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=3)

# 모델 구조 출력
print("=== 모델 구조 ===")
print(model)

# 각 레이어별 파라미터 확인
print("\n=== 레이어별 파라미터 ===")
for name, param in model.named_parameters():
    print(f"{name}: {param.shape}")

# 모델 상세 정보 추가 분석
print("=== EfficientNet-B0 상세 정보 ===")
print(f"입력 이미지 크기: {IMAGE_SIZE}x{IMAGE_SIZE}")
print(f"분류 클래스 수: {len(train_ds.classes)}")
print(f"클래스 목록: {class_names}")

# 총 파라미터 수 계산
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\n=== 파라미터 정보 ===")
print(f"전체 파라미터: {total_params:,}")
print(f"학습 가능한 파라미터: {trainable_params:,}")

# 모델 요약 (torchsummary 설치 필요)
try:
    from torchsummary import summary
    print(f"\n=== 모델 요약 ===")
    summary(model, (3, IMAGE_SIZE, IMAGE_SIZE))
except ImportError:
    print("torchsummary가 설치되지 않음. pip install torchsummary로 설치하세요.")

# 분류기 구조 상세 확인
print(f"\n=== 분류기 구조 ===")
print(f"분류기: {model.classifier}")
print(f"최종 Linear 레이어 입력 차원: {model.classifier[1].in_features}")
print(f"최종 Linear 레이어 출력 차원: {model.classifier[1].out_features}")
# Out:
# === 모델 구조 ===
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=22, bias=True)
#   )
# )
#
# === 레이어별 파라미터 ===
# features.0.0.weight: torch.Size([32, 3, 3, 3])
# features.0.1.weight: torch.Size([32])
# features.0.1.bias: torch.Size([32])
# features.1.0.block.0.0.weight: torch.Size([32, 1, 3, 3])
# features.1.0.block.0.1.weight: torch.Size([32])
# features.1.0.block.0.1.bias: torch.Size([32])
# features.1.0.block.1.fc1.weight: torch.Size([8, 32, 1, 1])
# features.1.0.block.1.fc1.bias: torch.Size([8])
# features.1.0.block.1.fc2.weight: torch.Size([32, 8, 1, 1])
# features.1.0.block.1.fc2.bias: torch.Size([32])
# features.1.0.block.2.0.weight: torch.Size([16, 32, 1, 1])
# features.1.0.block.2.1.weight: torch.Size([16])
# features.1.0.block.2.1.bias: torch.Size([16])
# features.2.0.block.0.0.weight: torch.Size([96, 16, 1, 1])
# features.2.0.block.0.1.weight: torch.Size([96])
# features.2.0.block.0.1.bias: torch.Size([96])
# features.2.0.block.1.0.weight: torch.Size([96, 1, 3, 3])
# features.2.0.block.1.1.weight: torch.Size([96])
# features.2.0.block.1.1.bias: torch.Size([96])
# features.2.0.block.2.fc1.weight: torch.Size([4, 96, 1, 1])
# features.2.0.block.2.fc1.bias: torch.Size([4])
# features.2.0.block.2.fc2.weight: torch.Size([96, 4, 1, 1])
# features.2.0.block.2.fc2.bias: torch.Size([96])
# features.2.0.block.3.0.weight: torch.Size([24, 96, 1, 1])
# features.2.0.block.3.1.weight: torch.Size([24])
# features.2.0.block.3.1.bias: torch.Size([24])
# features.2.1.block.0.0.weight: torch.Size([144, 24, 1, 1])
# features.2.1.block.0.1.weight: torch.Size([144])
# features.2.1.block.0.1.bias: torch.Size([144])
# features.2.1.block.1.0.weight: torch.Size([144, 1, 3, 3])
# features.2.1.block.1.1.weight: torch.Size([144])
# features.2.1.block.1.1.bias: torch.Size([144])
# features.2.1.block.2.fc1.weight: torch.Size([6, 144, 1, 1])
# features.2.1.block.2.fc1.bias: torch.Size([6])
# features.2.1.block.2.fc2.weight: torch.Size([144, 6, 1, 1])
# features.2.1.block.2.fc2.bias: torch.Size([144])
# features.2.1.block.3.0.weight: torch.Size([24, 144, 1, 1])
# features.2.1.block.3.1.weight: torch.Size([24])
# features.2.1.block.3.1.bias: torch.Size([24])
# features.3.0.block.0.0.weight: torch.Size([144, 24, 1, 1])
# features.3.0.block.0.1.weight: torch.Size([144])
# features.3.0.block.0.1.bias: torch.Size([144])
# features.3.0.block.1.0.weight: torch.Size([144, 1, 5, 5])
# features.3.0.block.1.1.weight: torch.Size([144])
# features.3.0.block.1.1.bias: torch.Size([144])
# features.3.0.block.2.fc1.weight: torch.Size([6, 144, 1, 1])
# features.3.0.block.2.fc1.bias: torch.Size([6])
# features.3.0.block.2.fc2.weight: torch.Size([144, 6, 1, 1])
# features.3.0.block.2.fc2.bias: torch.Size([144])
# features.3.0.block.3.0.weight: torch.Size([40, 144, 1, 1])
# features.3.0.block.3.1.weight: torch.Size([40])
# features.3.0.block.3.1.bias: torch.Size([40])
# features.3.1.block.0.0.weight: torch.Size([240, 40, 1, 1])
# features.3.1.block.0.1.weight: torch.Size([240])
# features.3.1.block.0.1.bias: torch.Size([240])
# features.3.1.block.1.0.weight: torch.Size([240, 1, 5, 5])
# features.3.1.block.1.1.weight: torch.Size([240])
# features.3.1.block.1.1.bias: torch.Size([240])
# features.3.1.block.2.fc1.weight: torch.Size([10, 240, 1, 1])
# features.3.1.block.2.fc1.bias: torch.Size([10])
# features.3.1.block.2.fc2.weight: torch.Size([240, 10, 1, 1])
# features.3.1.block.2.fc2.bias: torch.Size([240])
# features.3.1.block.3.0.weight: torch.Size([40, 240, 1, 1])
# features.3.1.block.3.1.weight: torch.Size([40])
# features.3.1.block.3.1.bias: torch.Size([40])
# features.4.0.block.0.0.weight: torch.Size([240, 40, 1, 1])
# features.4.0.block.0.1.weight: torch.Size([240])
# features.4.0.block.0.1.bias: torch.Size([240])
# features.4.0.block.1.0.weight: torch.Size([240, 1, 3, 3])
# features.4.0.block.1.1.weight: torch.Size([240])
# features.4.0.block.1.1.bias: torch.Size([240])
# features.4.0.block.2.fc1.weight: torch.Size([10, 240, 1, 1])
# features.4.0.block.2.fc1.bias: torch.Size([10])
# features.4.0.block.2.fc2.weight: torch.Size([240, 10, 1, 1])
# features.4.0.block.2.fc2.bias: torch.Size([240])
# features.4.0.block.3.0.weight: torch.Size([80, 240, 1, 1])
# features.4.0.block.3.1.weight: torch.Size([80])
# features.4.0.block.3.1.bias: torch.Size([80])
# features.4.1.block.0.0.weight: torch.Size([480, 80, 1, 1])
# features.4.1.block.0.1.weight: torch.Size([480])
# features.4.1.block.0.1.bias: torch.Size([480])
# features.4.1.block.1.0.weight: torch.Size([480, 1, 3, 3])
# features.4.1.block.1.1.weight: torch.Size([480])
# features.4.1.block.1.1.bias: torch.Size([480])
# features.4.1.block.2.fc1.weight: torch.Size([20, 480, 1, 1])
# features.4.1.block.2.fc1.bias: torch.Size([20])
# features.4.1.block.2.fc2.weight: torch.Size([480, 20, 1, 1])
# features.4.1.block.2.fc2.bias: torch.Size([480])
# features.4.1.block.3.0.weight: torch.Size([80, 480, 1, 1])
# features.4.1.block.3.1.weight: torch.Size([80])
# features.4.1.block.3.1.bias: torch.Size([80])
# features.4.2.block.0.0.weight: torch.Size([480, 80, 1, 1])
# features.4.2.block.0.1.weight: torch.Size([480])
# features.4.2.block.0.1.bias: torch.Size([480])
# features.4.2.block.1.0.weight: torch.Size([480, 1, 3, 3])
# features.4.2.block.1.1.weight: torch.Size([480])
# features.4.2.block.1.1.bias: torch.Size([480])
# features.4.2.block.2.fc1.weight: torch.Size([20, 480, 1, 1])
# features.4.2.block.2.fc1.bias: torch.Size([20])
# features.4.2.block.2.fc2.weight: torch.Size([480, 20, 1, 1])
# features.4.2.block.2.fc2.bias: torch.Size([480])
# features.4.2.block.3.0.weight: torch.Size([80, 480, 1, 1])
# features.4.2.block.3.1.weight: torch.Size([80])
# features.4.2.block.3.1.bias: torch.Size([80])
# features.5.0.block.0.0.weight: torch.Size([480, 80, 1, 1])
# features.5.0.block.0.1.weight: torch.Size([480])
# features.5.0.block.0.1.bias: torch.Size([480])
# features.5.0.block.1.0.weight: torch.Size([480, 1, 5, 5])
# features.5.0.block.1.1.weight: torch.Size([480])
# features.5.0.block.1.1.bias: torch.Size([480])
# features.5.0.block.2.fc1.weight: torch.Size([20, 480, 1, 1])
# features.5.0.block.2.fc1.bias: torch.Size([20])
# features.5.0.block.2.fc2.weight: torch.Size([480, 20, 1, 1])
# features.5.0.block.2.fc2.bias: torch.Size([480])
# features.5.0.block.3.0.weight: torch.Size([112, 480, 1, 1])
# features.5.0.block.3.1.weight: torch.Size([112])
# features.5.0.block.3.1.bias: torch.Size([112])
# features.5.1.block.0.0.weight: torch.Size([672, 112, 1, 1])
# features.5.1.block.0.1.weight: torch.Size([672])
# features.5.1.block.0.1.bias: torch.Size([672])
# features.5.1.block.1.0.weight: torch.Size([672, 1, 5, 5])
# features.5.1.block.1.1.weight: torch.Size([672])
# features.5.1.block.1.1.bias: torch.Size([672])
# features.5.1.block.2.fc1.weight: torch.Size([28, 672, 1, 1])
# features.5.1.block.2.fc1.bias: torch.Size([28])
# features.5.1.block.2.fc2.weight: torch.Size([672, 28, 1, 1])
# features.5.1.block.2.fc2.bias: torch.Size([672])
# features.5.1.block.3.0.weight: torch.Size([112, 672, 1, 1])
# features.5.1.block.3.1.weight: torch.Size([112])
# features.5.1.block.3.1.bias: torch.Size([112])
# features.5.2.block.0.0.weight: torch.Size([672, 112, 1, 1])
# features.5.2.block.0.1.weight: torch.Size([672])
# features.5.2.block.0.1.bias: torch.Size([672])
# features.5.2.block.1.0.weight: torch.Size([672, 1, 5, 5])
# features.5.2.block.1.1.weight: torch.Size([672])
# features.5.2.block.1.1.bias: torch.Size([672])
# features.5.2.block.2.fc1.weight: torch.Size([28, 672, 1, 1])
# features.5.2.block.2.fc1.bias: torch.Size([28])
# features.5.2.block.2.fc2.weight: torch.Size([672, 28, 1, 1])
# features.5.2.block.2.fc2.bias: torch.Size([672])
# features.5.2.block.3.0.weight: torch.Size([112, 672, 1, 1])
# features.5.2.block.3.1.weight: torch.Size([112])
# features.5.2.block.3.1.bias: torch.Size([112])
# features.6.0.block.0.0.weight: torch.Size([672, 112, 1, 1])
# features.6.0.block.0.1.weight: torch.Size([672])
# features.6.0.block.0.1.bias: torch.Size([672])
# features.6.0.block.1.0.weight: torch.Size([672, 1, 5, 5])
# features.6.0.block.1.1.weight: torch.Size([672])
# features.6.0.block.1.1.bias: torch.Size([672])
# features.6.0.block.2.fc1.weight: torch.Size([28, 672, 1, 1])
# features.6.0.block.2.fc1.bias: torch.Size([28])
# features.6.0.block.2.fc2.weight: torch.Size([672, 28, 1, 1])
# features.6.0.block.2.fc2.bias: torch.Size([672])
# features.6.0.block.3.0.weight: torch.Size([192, 672, 1, 1])
# features.6.0.block.3.1.weight: torch.Size([192])
# features.6.0.block.3.1.bias: torch.Size([192])
# features.6.1.block.0.0.weight: torch.Size([1152, 192, 1, 1])
# features.6.1.block.0.1.weight: torch.Size([1152])
# features.6.1.block.0.1.bias: torch.Size([1152])
# features.6.1.block.1.0.weight: torch.Size([1152, 1, 5, 5])
# features.6.1.block.1.1.weight: torch.Size([1152])
# features.6.1.block.1.1.bias: torch.Size([1152])
# features.6.1.block.2.fc1.weight: torch.Size([48, 1152, 1, 1])
# features.6.1.block.2.fc1.bias: torch.Size([48])
# features.6.1.block.2.fc2.weight: torch.Size([1152, 48, 1, 1])
# features.6.1.block.2.fc2.bias: torch.Size([1152])
# features.6.1.block.3.0.weight: torch.Size([192, 1152, 1, 1])
# features.6.1.block.3.1.weight: torch.Size([192])
# features.6.1.block.3.1.bias: torch.Size([192])
# features.6.2.block.0.0.weight: torch.Size([1152, 192, 1, 1])
# features.6.2.block.0.1.weight: torch.Size([1152])
# features.6.2.block.0.1.bias: torch.Size([1152])
# features.6.2.block.1.0.weight: torch.Size([1152, 1, 5, 5])
# features.6.2.block.1.1.weight: torch.Size([1152])
# features.6.2.block.1.1.bias: torch.Size([1152])
# features.6.2.block.2.fc1.weight: torch.Size([48, 1152, 1, 1])
# features.6.2.block.2.fc1.bias: torch.Size([48])
# features.6.2.block.2.fc2.weight: torch.Size([1152, 48, 1, 1])
# features.6.2.block.2.fc2.bias: torch.Size([1152])
# features.6.2.block.3.0.weight: torch.Size([192, 1152, 1, 1])
# features.6.2.block.3.1.weight: torch.Size([192])
# features.6.2.block.3.1.bias: torch.Size([192])
# features.6.3.block.0.0.weight: torch.Size([1152, 192, 1, 1])
# features.6.3.block.0.1.weight: torch.Size([1152])
# features.6.3.block.0.1.bias: torch.Size([1152])
# features.6.3.block.1.0.weight: torch.Size([1152, 1, 5, 5])
# features.6.3.block.1.1.weight: torch.Size([1152])
# features.6.3.block.1.1.bias: torch.Size([1152])
# features.6.3.block.2.fc1.weight: torch.Size([48, 1152, 1, 1])
# features.6.3.block.2.fc1.bias: torch.Size([48])
# features.6.3.block.2.fc2.weight: torch.Size([1152, 48, 1, 1])
# features.6.3.block.2.fc2.bias: torch.Size([1152])
# features.6.3.block.3.0.weight: torch.Size([192, 1152, 1, 1])
# features.6.3.block.3.1.weight: torch.Size([192])
# features.6.3.block.3.1.bias: torch.Size([192])
# features.7.0.block.0.0.weight: torch.Size([1152, 192, 1, 1])
# features.7.0.block.0.1.weight: torch.Size([1152])
# features.7.0.block.0.1.bias: torch.Size([1152])
# features.7.0.block.1.0.weight: torch.Size([1152, 1, 3, 3])
# features.7.0.block.1.1.weight: torch.Size([1152])
# features.7.0.block.1.1.bias: torch.Size([1152])
# features.7.0.block.2.fc1.weight: torch.Size([48, 1152, 1, 1])
# features.7.0.block.2.fc1.bias: torch.Size([48])
# features.7.0.block.2.fc2.weight: torch.Size([1152, 48, 1, 1])
# features.7.0.block.2.fc2.bias: torch.Size([1152])
# features.7.0.block.3.0.weight: torch.Size([320, 1152, 1, 1])
# features.7.0.block.3.1.weight: torch.Size([320])
# features.7.0.block.3.1.bias: torch.Size([320])
# features.8.0.weight: torch.Size([1280, 320, 1, 1])
# features.8.1.weight: torch.Size([1280])
# features.8.1.bias: torch.Size([1280])
# classifier.1.weight: torch.Size([22, 1280])
# classifier.1.bias: torch.Size([22])
# === EfficientNet-B0 상세 정보 ===
# 입력 이미지 크기: 224x224
# 분류 클래스 수: 22
# 클래스 목록: ['Acne', 'Actinic_Keratosis', 'Benign_tumors', 'Bullous', 'Candidiasis', 'DrugEruption', 'Eczema', 'Infestations_Bites', 'Lichen', 'Lupus', 'Moles', 'Psoriasis', 'Rosacea', 'Seborrh_Keratoses', 'SkinCancer', 'Sun_Sunlight_Damage', 'Tinea', 'Unknown_Normal', 'Vascular_Tumors', 'Vasculitis', 'Vitiligo', 'Warts']
#
# === 파라미터 정보 ===
# 전체 파라미터: 4,035,730
# 학습 가능한 파라미터: 4,035,730
# torchsummary가 설치되지 않음. pip install torchsummary로 설치하세요.
#
# === 분류기 구조 ===
# 분류기: Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=22, bias=True)
# )
# 최종 Linear 레이어 입력 차원: 1280
# 최종 Linear 레이어 출력 차원: 22

# %%
# 6. 개선된 학습 루프 (중간 저장, 상세 로깅, 에러 처리 포함)
import time
import copy
from datetime import datetime

EPOCHS = 20  # 원래 에폭 수
best_val_acc = 0
patience, counter = 5, 0

# 다양한 체크포인트 경로 설정
checkpoint_path = os.path.join(results_dir, f'best_efficientnet.pth')
latest_checkpoint = os.path.join(results_dir, f'latest_efficientnet.pth')
periodic_checkpoint_dir = os.path.join(results_dir, 'periodic_checkpoints')
os.makedirs(periodic_checkpoint_dir, exist_ok=True)

log_path = os.path.join(results_dir, 'train_log.txt')
metrics_log_path = os.path.join(results_dir, 'metrics_log.csv')

# 메트릭 로깅을 위한 리스트
train_losses, val_losses = [], []
train_accs, val_accs = [], []
log_lines = []

# 메트릭 CSV 헤더 생성
with open(metrics_log_path, 'w', encoding='utf-8') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc,learning_rate,timestamp\n')

print("🚀 학습 시작!")
print(f"📁 결과 저장 위치: {results_dir}")
print(f"🎯 목표 에폭: {EPOCHS}")
print(f"⏰ Early stopping patience: {patience}")
print(f"💾 체크포인트 저장 간격: 매 에폭")
print("-" * 50)

start_time = time.time()

try:
    for epoch in range(1, EPOCHS+1):
        epoch_start_time = time.time()
        
        # =========================
        # 훈련 단계
        # =========================
        model.train()
        train_loss = train_correct = train_total = 0
        
        for batch_idx, (imgs, labels) in enumerate(train_loader):
            imgs, labels = imgs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * imgs.size(0)
            _, preds = outputs.max(1)
            train_correct += preds.eq(labels).sum().item()
            train_total += labels.size(0)
            
            # 배치마다 진행 상황 출력 (매 10번째 배치)
            if batch_idx % 10 == 0 and batch_idx > 0:
                current_loss = train_loss / train_total
                current_acc = train_correct / train_total
                print(f"  Epoch {epoch}/{EPOCHS} - Batch {batch_idx}/{len(train_loader)} - Loss: {current_loss:.4f}, Acc: {current_acc:.4f}")
        
        train_loss = train_loss / train_total if train_total > 0 else 0
        train_acc = train_correct / train_total if train_total > 0 else 0
        
        # =========================
        # 검증 단계
        # =========================
        model.eval()
        val_loss = val_correct = val_total = 0
        
        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item() * imgs.size(0)
                _, preds = outputs.max(1)
                val_correct += preds.eq(labels).sum().item()
                val_total += labels.size(0)
        
        val_loss = val_loss / val_total if val_total > 0 else 0
        val_acc = val_correct / val_total if val_total > 0 else 0
        
        # 스케줄러 업데이트
        current_lr = optimizer.param_groups[0]['lr']
        scheduler.step(val_acc)
        
        # 메트릭 저장
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        
        # 에폭 시간 계산
        epoch_time = time.time() - epoch_start_time
        
        # =========================
        # 로깅 및 출력
        # =========================
        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        log_line = f'Epoch {epoch}/{EPOCHS} ({epoch_time:.1f}s) - Train: Loss={train_loss:.4f}, Acc={train_acc:.4f} | Val: Loss={val_loss:.4f}, Acc={val_acc:.4f} | LR={current_lr:.2e}'
        print(log_line)
        log_lines.append(log_line)
        
        # CSV 메트릭 로그 저장
        with open(metrics_log_path, 'a', encoding='utf-8') as f:
            f.write(f'{epoch},{train_loss:.6f},{train_acc:.6f},{val_loss:.6f},{val_acc:.6f},{current_lr:.2e},{timestamp}\n')
        
        # =========================
        # 모델 저장 (중간 저장 포함)
        # =========================
        
        # 1. 매 에폭마다 최신 모델 저장
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'train_loss': train_loss,
            'val_loss': val_loss,
            'train_acc': train_acc,
            'val_acc': val_acc,
            'best_val_acc': best_val_acc,
        }, latest_checkpoint)
        
        # 2. 베스트 모델 저장
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            
            # 베스트 모델 저장 (전체 정보 포함)
            torch.save({
                'epoch': epoch,
                'model_state_dict': copy.deepcopy(model.state_dict()),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'train_loss': train_loss,
                'val_loss': val_loss,
                'train_acc': train_acc,
                'val_acc': val_acc,
                'best_val_acc': best_val_acc,
                'class_names': class_names,
                'model_config': {
                    'model_name': 'efficientnet_b0',
                    'num_classes': len(class_names),
                    'image_size': IMAGE_SIZE,
                    'batch_size': BATCH_SIZE,
                }
            }, checkpoint_path)
            
            print(f'📌 새로운 베스트 모델 저장! Val Acc: {val_acc:.4f}')
            log_lines.append(f'Best model saved at epoch {epoch} with val_acc: {val_acc:.4f}')
            counter = 0
        else:
            counter += 1
        
        # 3. 주기적 체크포인트 저장 (매 5 에폭마다)
        if epoch % 5 == 0:
            periodic_checkpoint = os.path.join(periodic_checkpoint_dir, f'model_epoch_{epoch:03d}.pth')
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'val_acc': val_acc,
                'train_acc': train_acc,
            }, periodic_checkpoint)
            print(f'💾 주기적 체크포인트 저장: epoch_{epoch:03d}')
        
        # =========================
        # Early Stopping 확인
        # =========================
        if counter >= patience:
            print(f'⏹️ Early stopping triggered at epoch {epoch}')
            print(f'🏆 Best validation accuracy: {best_val_acc:.4f}')
            log_lines.append(f'Early stopping at epoch {epoch}')
            break
        
        # 남은 patience 표시
        if counter > 0:
            print(f"⚠️ Early stopping counter: {counter}/{patience}")

except KeyboardInterrupt:
    print("\n🛑 학습이 사용자에 의해 중단되었습니다.")
    log_lines.append("Training interrupted by user")
except Exception as e:
    print(f"\n❌ 학습 중 오류 발생: {e}")
    log_lines.append(f"Training error: {str(e)}")
finally:
    # 최종 로그 저장
    total_time = time.time() - start_time
    final_log = f"\n학습 완료!\n총 소요 시간: {total_time/60:.1f}분\n최고 검증 정확도: {best_val_acc:.4f}"
    print(final_log)
    log_lines.append(final_log)
    
    # 텍스트 로그 파일 저장
    with open(log_path, 'w', encoding='utf-8') as f:
        for line in log_lines:
            f.write(line + '\n')

# 베스트 모델 로드
if os.path.exists(checkpoint_path):
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f'✅ 베스트 모델 로드 완료! (에폭 {checkpoint["epoch"]}, Val Acc: {checkpoint["val_acc"]:.4f})')
else:
    print('⚠️ 베스트 모델 파일을 찾을 수 없습니다. 현재 모델 상태를 유지합니다.')
# Out:
# 🚀 학습 시작!
# 📁 결과 저장 위치: results\20251021_145847
# 🎯 목표 에폭: 20
# ⏰ Early stopping patience: 5
# 💾 체크포인트 저장 간격: 매 에폭
# --------------------------------------------------
#   Epoch 1/20 - Batch 10/435 - Loss: 3.0981, Acc: 0.0852
#   Epoch 1/20 - Batch 10/435 - Loss: 3.0981, Acc: 0.0852
#   Epoch 1/20 - Batch 20/435 - Loss: 3.0876, Acc: 0.0848
#   Epoch 1/20 - Batch 20/435 - Loss: 3.0876, Acc: 0.0848
#   Epoch 1/20 - Batch 30/435 - Loss: 3.0585, Acc: 0.1079
#   Epoch 1/20 - Batch 30/435 - Loss: 3.0585, Acc: 0.1079
#   Epoch 1/20 - Batch 40/435 - Loss: 3.0322, Acc: 0.1204
#   Epoch 1/20 - Batch 40/435 - Loss: 3.0322, Acc: 0.1204
#   Epoch 1/20 - Batch 50/435 - Loss: 3.0101, Acc: 0.1305
#   Epoch 1/20 - Batch 50/435 - Loss: 3.0101, Acc: 0.1305
#   Epoch 1/20 - Batch 60/435 - Loss: 2.9862, Acc: 0.1511
#   Epoch 1/20 - Batch 60/435 - Loss: 2.9862, Acc: 0.1511
#   Epoch 1/20 - Batch 70/435 - Loss: 2.9581, Acc: 0.1611
#   Epoch 1/20 - Batch 70/435 - Loss: 2.9581, Acc: 0.1611
#   Epoch 1/20 - Batch 80/435 - Loss: 2.9336, Acc: 0.1759
#   Epoch 1/20 - Batch 80/435 - Loss: 2.9336, Acc: 0.1759
#   Epoch 1/20 - Batch 90/435 - Loss: 2.9093, Acc: 0.1868
#   Epoch 1/20 - Batch 90/435 - Loss: 2.9093, Acc: 0.1868
#   Epoch 1/20 - Batch 100/435 - Loss: 2.8850, Acc: 0.1946
#   Epoch 1/20 - Batch 100/435 - Loss: 2.8850, Acc: 0.1946
#   Epoch 1/20 - Batch 110/435 - Loss: 2.8606, Acc: 0.2072
#   Epoch 1/20 - Batch 110/435 - Loss: 2.8606, Acc: 0.2072
#   Epoch 1/20 - Batch 120/435 - Loss: 2.8407, Acc: 0.2115
#   Epoch 1/20 - Batch 120/435 - Loss: 2.8407, Acc: 0.2115
#   Epoch 1/20 - Batch 130/435 - Loss: 2.8216, Acc: 0.2185
#   Epoch 1/20 - Batch 130/435 - Loss: 2.8216, Acc: 0.2185
#   Epoch 1/20 - Batch 140/435 - Loss: 2.7964, Acc: 0.2238
#   Epoch 1/20 - Batch 140/435 - Loss: 2.7964, Acc: 0.2238
#   Epoch 1/20 - Batch 150/435 - Loss: 2.7742, Acc: 0.2316
#   Epoch 1/20 - Batch 150/435 - Loss: 2.7742, Acc: 0.2316
#   Epoch 1/20 - Batch 160/435 - Loss: 2.7482, Acc: 0.2401
#   Epoch 1/20 - Batch 160/435 - Loss: 2.7482, Acc: 0.2401
#   Epoch 1/20 - Batch 170/435 - Loss: 2.7238, Acc: 0.2476
#   Epoch 1/20 - Batch 170/435 - Loss: 2.7238, Acc: 0.2476
#   Epoch 1/20 - Batch 180/435 - Loss: 2.7001, Acc: 0.2533
#   Epoch 1/20 - Batch 180/435 - Loss: 2.7001, Acc: 0.2533
#   Epoch 1/20 - Batch 190/435 - Loss: 2.6784, Acc: 0.2593
#   Epoch 1/20 - Batch 190/435 - Loss: 2.6784, Acc: 0.2593
#   Epoch 1/20 - Batch 200/435 - Loss: 2.6550, Acc: 0.2649
#   Epoch 1/20 - Batch 200/435 - Loss: 2.6550, Acc: 0.2649
#   Epoch 1/20 - Batch 210/435 - Loss: 2.6311, Acc: 0.2707
#   Epoch 1/20 - Batch 210/435 - Loss: 2.6311, Acc: 0.2707
#   Epoch 1/20 - Batch 220/435 - Loss: 2.6073, Acc: 0.2763
#   Epoch 1/20 - Batch 220/435 - Loss: 2.6073, Acc: 0.2763
#   Epoch 1/20 - Batch 230/435 - Loss: 2.5854, Acc: 0.2822
#   Epoch 1/20 - Batch 230/435 - Loss: 2.5854, Acc: 0.2822
#   Epoch 1/20 - Batch 240/435 - Loss: 2.5670, Acc: 0.2880
#   Epoch 1/20 - Batch 240/435 - Loss: 2.5670, Acc: 0.2880
#   Epoch 1/20 - Batch 250/435 - Loss: 2.5500, Acc: 0.2923
#   Epoch 1/20 - Batch 250/435 - Loss: 2.5500, Acc: 0.2923
#   Epoch 1/20 - Batch 260/435 - Loss: 2.5351, Acc: 0.2972
#   Epoch 1/20 - Batch 260/435 - Loss: 2.5351, Acc: 0.2972
#   Epoch 1/20 - Batch 270/435 - Loss: 2.5168, Acc: 0.3025
#   Epoch 1/20 - Batch 270/435 - Loss: 2.5168, Acc: 0.3025
#   Epoch 1/20 - Batch 280/435 - Loss: 2.4992, Acc: 0.3068
#   Epoch 1/20 - Batch 280/435 - Loss: 2.4992, Acc: 0.3068
#   Epoch 1/20 - Batch 290/435 - Loss: 2.4845, Acc: 0.3115
#   Epoch 1/20 - Batch 290/435 - Loss: 2.4845, Acc: 0.3115
#   Epoch 1/20 - Batch 300/435 - Loss: 2.4712, Acc: 0.3138
#   Epoch 1/20 - Batch 300/435 - Loss: 2.4712, Acc: 0.3138
#   Epoch 1/20 - Batch 310/435 - Loss: 2.4543, Acc: 0.3173
#   Epoch 1/20 - Batch 310/435 - Loss: 2.4543, Acc: 0.3173
#   Epoch 1/20 - Batch 320/435 - Loss: 2.4397, Acc: 0.3208
#   Epoch 1/20 - Batch 320/435 - Loss: 2.4397, Acc: 0.3208
#   Epoch 1/20 - Batch 330/435 - Loss: 2.4265, Acc: 0.3241
#   Epoch 1/20 - Batch 330/435 - Loss: 2.4265, Acc: 0.3241
#   Epoch 1/20 - Batch 340/435 - Loss: 2.4070, Acc: 0.3289
#   Epoch 1/20 - Batch 340/435 - Loss: 2.4070, Acc: 0.3289
#   Epoch 1/20 - Batch 350/435 - Loss: 2.3907, Acc: 0.3327
#   Epoch 1/20 - Batch 350/435 - Loss: 2.3907, Acc: 0.3327
#   Epoch 1/20 - Batch 360/435 - Loss: 2.3796, Acc: 0.3361
#   Epoch 1/20 - Batch 360/435 - Loss: 2.3796, Acc: 0.3361
#   Epoch 1/20 - Batch 370/435 - Loss: 2.3647, Acc: 0.3392
#   Epoch 1/20 - Batch 370/435 - Loss: 2.3647, Acc: 0.3392
#   Epoch 1/20 - Batch 380/435 - Loss: 2.3532, Acc: 0.3418
#   Epoch 1/20 - Batch 380/435 - Loss: 2.3532, Acc: 0.3418
#   Epoch 1/20 - Batch 390/435 - Loss: 2.3415, Acc: 0.3445
#   Epoch 1/20 - Batch 390/435 - Loss: 2.3415, Acc: 0.3445
#   Epoch 1/20 - Batch 400/435 - Loss: 2.3284, Acc: 0.3479
#   Epoch 1/20 - Batch 400/435 - Loss: 2.3284, Acc: 0.3479
#   Epoch 1/20 - Batch 410/435 - Loss: 2.3219, Acc: 0.3489
#   Epoch 1/20 - Batch 410/435 - Loss: 2.3219, Acc: 0.3489
#   Epoch 1/20 - Batch 420/435 - Loss: 2.3120, Acc: 0.3512
#   Epoch 1/20 - Batch 420/435 - Loss: 2.3120, Acc: 0.3512
#   Epoch 1/20 - Batch 430/435 - Loss: 2.3000, Acc: 0.3535
#   Epoch 1/20 - Batch 430/435 - Loss: 2.3000, Acc: 0.3535
# Epoch 1/20 (195.4s) - Train: Loss=2.2963, Acc=0.3544 | Val: Loss=1.6124, Acc=0.4974 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.4974
# Epoch 1/20 (195.4s) - Train: Loss=2.2963, Acc=0.3544 | Val: Loss=1.6124, Acc=0.4974 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.4974
#   Epoch 2/20 - Batch 10/435 - Loss: 1.6792, Acc: 0.5170
#   Epoch 2/20 - Batch 10/435 - Loss: 1.6792, Acc: 0.5170
#   Epoch 2/20 - Batch 20/435 - Loss: 1.6522, Acc: 0.5149
#   Epoch 2/20 - Batch 20/435 - Loss: 1.6522, Acc: 0.5149
#   Epoch 2/20 - Batch 30/435 - Loss: 1.6575, Acc: 0.5242
#   Epoch 2/20 - Batch 30/435 - Loss: 1.6575, Acc: 0.5242
#   Epoch 2/20 - Batch 40/435 - Loss: 1.6674, Acc: 0.5191
#   Epoch 2/20 - Batch 40/435 - Loss: 1.6674, Acc: 0.5191
#   Epoch 2/20 - Batch 50/435 - Loss: 1.6689, Acc: 0.5129
#   Epoch 2/20 - Batch 50/435 - Loss: 1.6689, Acc: 0.5129
#   Epoch 2/20 - Batch 60/435 - Loss: 1.6786, Acc: 0.5087
#   Epoch 2/20 - Batch 60/435 - Loss: 1.6786, Acc: 0.5087
#   Epoch 2/20 - Batch 70/435 - Loss: 1.6957, Acc: 0.5048
#   Epoch 2/20 - Batch 70/435 - Loss: 1.6957, Acc: 0.5048
#   Epoch 2/20 - Batch 80/435 - Loss: 1.6776, Acc: 0.5108
#   Epoch 2/20 - Batch 80/435 - Loss: 1.6776, Acc: 0.5108
#   Epoch 2/20 - Batch 90/435 - Loss: 1.6701, Acc: 0.5106
#   Epoch 2/20 - Batch 90/435 - Loss: 1.6701, Acc: 0.5106
#   Epoch 2/20 - Batch 100/435 - Loss: 1.6570, Acc: 0.5121
#   Epoch 2/20 - Batch 100/435 - Loss: 1.6570, Acc: 0.5121
#   Epoch 2/20 - Batch 110/435 - Loss: 1.6683, Acc: 0.5096
#   Epoch 2/20 - Batch 110/435 - Loss: 1.6683, Acc: 0.5096
#   Epoch 2/20 - Batch 120/435 - Loss: 1.6578, Acc: 0.5137
#   Epoch 2/20 - Batch 120/435 - Loss: 1.6578, Acc: 0.5137
#   Epoch 2/20 - Batch 130/435 - Loss: 1.6460, Acc: 0.5177
#   Epoch 2/20 - Batch 130/435 - Loss: 1.6460, Acc: 0.5177
#   Epoch 2/20 - Batch 140/435 - Loss: 1.6417, Acc: 0.5197
#   Epoch 2/20 - Batch 140/435 - Loss: 1.6417, Acc: 0.5197
#   Epoch 2/20 - Batch 150/435 - Loss: 1.6329, Acc: 0.5209
#   Epoch 2/20 - Batch 150/435 - Loss: 1.6329, Acc: 0.5209
#   Epoch 2/20 - Batch 160/435 - Loss: 1.6289, Acc: 0.5202
#   Epoch 2/20 - Batch 160/435 - Loss: 1.6289, Acc: 0.5202
#   Epoch 2/20 - Batch 170/435 - Loss: 1.6285, Acc: 0.5203
#   Epoch 2/20 - Batch 170/435 - Loss: 1.6285, Acc: 0.5203
#   Epoch 2/20 - Batch 180/435 - Loss: 1.6267, Acc: 0.5207
#   Epoch 2/20 - Batch 180/435 - Loss: 1.6267, Acc: 0.5207
#   Epoch 2/20 - Batch 190/435 - Loss: 1.6172, Acc: 0.5254
#   Epoch 2/20 - Batch 190/435 - Loss: 1.6172, Acc: 0.5254
#   Epoch 2/20 - Batch 200/435 - Loss: 1.6172, Acc: 0.5252
#   Epoch 2/20 - Batch 200/435 - Loss: 1.6172, Acc: 0.5252
#   Epoch 2/20 - Batch 210/435 - Loss: 1.6168, Acc: 0.5241
#   Epoch 2/20 - Batch 210/435 - Loss: 1.6168, Acc: 0.5241
#   Epoch 2/20 - Batch 220/435 - Loss: 1.6159, Acc: 0.5232
#   Epoch 2/20 - Batch 220/435 - Loss: 1.6159, Acc: 0.5232
#   Epoch 2/20 - Batch 230/435 - Loss: 1.6062, Acc: 0.5241
#   Epoch 2/20 - Batch 230/435 - Loss: 1.6062, Acc: 0.5241
#   Epoch 2/20 - Batch 240/435 - Loss: 1.5970, Acc: 0.5262
#   Epoch 2/20 - Batch 240/435 - Loss: 1.5970, Acc: 0.5262
#   Epoch 2/20 - Batch 250/435 - Loss: 1.5975, Acc: 0.5255
#   Epoch 2/20 - Batch 250/435 - Loss: 1.5975, Acc: 0.5255
#   Epoch 2/20 - Batch 260/435 - Loss: 1.5938, Acc: 0.5261
#   Epoch 2/20 - Batch 260/435 - Loss: 1.5938, Acc: 0.5261
#   Epoch 2/20 - Batch 270/435 - Loss: 1.5850, Acc: 0.5277
#   Epoch 2/20 - Batch 270/435 - Loss: 1.5850, Acc: 0.5277
#   Epoch 2/20 - Batch 280/435 - Loss: 1.5808, Acc: 0.5295
#   Epoch 2/20 - Batch 280/435 - Loss: 1.5808, Acc: 0.5295
#   Epoch 2/20 - Batch 290/435 - Loss: 1.5783, Acc: 0.5302
#   Epoch 2/20 - Batch 290/435 - Loss: 1.5783, Acc: 0.5302
#   Epoch 2/20 - Batch 300/435 - Loss: 1.5747, Acc: 0.5319
#   Epoch 2/20 - Batch 300/435 - Loss: 1.5747, Acc: 0.5319
#   Epoch 2/20 - Batch 310/435 - Loss: 1.5753, Acc: 0.5321
#   Epoch 2/20 - Batch 310/435 - Loss: 1.5753, Acc: 0.5321
#   Epoch 2/20 - Batch 320/435 - Loss: 1.5723, Acc: 0.5327
#   Epoch 2/20 - Batch 320/435 - Loss: 1.5723, Acc: 0.5327
#   Epoch 2/20 - Batch 330/435 - Loss: 1.5716, Acc: 0.5333
#   Epoch 2/20 - Batch 330/435 - Loss: 1.5716, Acc: 0.5333
#   Epoch 2/20 - Batch 340/435 - Loss: 1.5672, Acc: 0.5332
#   Epoch 2/20 - Batch 340/435 - Loss: 1.5672, Acc: 0.5332
#   Epoch 2/20 - Batch 350/435 - Loss: 1.5595, Acc: 0.5345
#   Epoch 2/20 - Batch 350/435 - Loss: 1.5595, Acc: 0.5345
#   Epoch 2/20 - Batch 360/435 - Loss: 1.5577, Acc: 0.5349
#   Epoch 2/20 - Batch 360/435 - Loss: 1.5577, Acc: 0.5349
#   Epoch 2/20 - Batch 370/435 - Loss: 1.5552, Acc: 0.5353
#   Epoch 2/20 - Batch 370/435 - Loss: 1.5552, Acc: 0.5353
#   Epoch 2/20 - Batch 380/435 - Loss: 1.5495, Acc: 0.5367
#   Epoch 2/20 - Batch 380/435 - Loss: 1.5495, Acc: 0.5367
#   Epoch 2/20 - Batch 390/435 - Loss: 1.5487, Acc: 0.5368
#   Epoch 2/20 - Batch 390/435 - Loss: 1.5487, Acc: 0.5368
#   Epoch 2/20 - Batch 400/435 - Loss: 1.5472, Acc: 0.5379
#   Epoch 2/20 - Batch 400/435 - Loss: 1.5472, Acc: 0.5379
#   Epoch 2/20 - Batch 410/435 - Loss: 1.5453, Acc: 0.5380
#   Epoch 2/20 - Batch 410/435 - Loss: 1.5453, Acc: 0.5380
#   Epoch 2/20 - Batch 420/435 - Loss: 1.5428, Acc: 0.5382
#   Epoch 2/20 - Batch 420/435 - Loss: 1.5428, Acc: 0.5382
#   Epoch 2/20 - Batch 430/435 - Loss: 1.5381, Acc: 0.5395
#   Epoch 2/20 - Batch 430/435 - Loss: 1.5381, Acc: 0.5395
# Epoch 2/20 (130.8s) - Train: Loss=1.5364, Acc=0.5399 | Val: Loss=1.2785, Acc=0.6028 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.6028
# Epoch 2/20 (130.8s) - Train: Loss=1.5364, Acc=0.5399 | Val: Loss=1.2785, Acc=0.6028 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.6028
#   Epoch 3/20 - Batch 10/435 - Loss: 1.3134, Acc: 0.6080
#   Epoch 3/20 - Batch 10/435 - Loss: 1.3134, Acc: 0.6080
#   Epoch 3/20 - Batch 20/435 - Loss: 1.2842, Acc: 0.6071
#   Epoch 3/20 - Batch 20/435 - Loss: 1.2842, Acc: 0.6071
#   Epoch 3/20 - Batch 30/435 - Loss: 1.2892, Acc: 0.6058
#   Epoch 3/20 - Batch 30/435 - Loss: 1.2892, Acc: 0.6058
#   Epoch 3/20 - Batch 40/435 - Loss: 1.2938, Acc: 0.6044
#   Epoch 3/20 - Batch 40/435 - Loss: 1.2938, Acc: 0.6044
#   Epoch 3/20 - Batch 50/435 - Loss: 1.2814, Acc: 0.6066
#   Epoch 3/20 - Batch 50/435 - Loss: 1.2814, Acc: 0.6066
#   Epoch 3/20 - Batch 60/435 - Loss: 1.2629, Acc: 0.6148
#   Epoch 3/20 - Batch 60/435 - Loss: 1.2629, Acc: 0.6148
#   Epoch 3/20 - Batch 70/435 - Loss: 1.2590, Acc: 0.6188
#   Epoch 3/20 - Batch 70/435 - Loss: 1.2590, Acc: 0.6188
#   Epoch 3/20 - Batch 80/435 - Loss: 1.2628, Acc: 0.6161
#   Epoch 3/20 - Batch 80/435 - Loss: 1.2628, Acc: 0.6161
#   Epoch 3/20 - Batch 90/435 - Loss: 1.2662, Acc: 0.6137
#   Epoch 3/20 - Batch 90/435 - Loss: 1.2662, Acc: 0.6137
#   Epoch 3/20 - Batch 100/435 - Loss: 1.2700, Acc: 0.6089
#   Epoch 3/20 - Batch 100/435 - Loss: 1.2700, Acc: 0.6089
#   Epoch 3/20 - Batch 110/435 - Loss: 1.2662, Acc: 0.6112
#   Epoch 3/20 - Batch 110/435 - Loss: 1.2662, Acc: 0.6112
#   Epoch 3/20 - Batch 120/435 - Loss: 1.2631, Acc: 0.6139
#   Epoch 3/20 - Batch 120/435 - Loss: 1.2631, Acc: 0.6139
#   Epoch 3/20 - Batch 130/435 - Loss: 1.2596, Acc: 0.6145
#   Epoch 3/20 - Batch 130/435 - Loss: 1.2596, Acc: 0.6145
#   Epoch 3/20 - Batch 140/435 - Loss: 1.2657, Acc: 0.6128
#   Epoch 3/20 - Batch 140/435 - Loss: 1.2657, Acc: 0.6128
#   Epoch 3/20 - Batch 150/435 - Loss: 1.2592, Acc: 0.6144
#   Epoch 3/20 - Batch 150/435 - Loss: 1.2592, Acc: 0.6144
#   Epoch 3/20 - Batch 160/435 - Loss: 1.2517, Acc: 0.6165
#   Epoch 3/20 - Batch 160/435 - Loss: 1.2517, Acc: 0.6165
#   Epoch 3/20 - Batch 170/435 - Loss: 1.2458, Acc: 0.6175
#   Epoch 3/20 - Batch 170/435 - Loss: 1.2458, Acc: 0.6175
#   Epoch 3/20 - Batch 180/435 - Loss: 1.2401, Acc: 0.6196
#   Epoch 3/20 - Batch 180/435 - Loss: 1.2401, Acc: 0.6196
#   Epoch 3/20 - Batch 190/435 - Loss: 1.2367, Acc: 0.6180
#   Epoch 3/20 - Batch 190/435 - Loss: 1.2367, Acc: 0.6180
#   Epoch 3/20 - Batch 200/435 - Loss: 1.2420, Acc: 0.6157
#   Epoch 3/20 - Batch 200/435 - Loss: 1.2420, Acc: 0.6157
#   Epoch 3/20 - Batch 210/435 - Loss: 1.2332, Acc: 0.6177
#   Epoch 3/20 - Batch 210/435 - Loss: 1.2332, Acc: 0.6177
#   Epoch 3/20 - Batch 220/435 - Loss: 1.2336, Acc: 0.6168
#   Epoch 3/20 - Batch 220/435 - Loss: 1.2336, Acc: 0.6168
#   Epoch 3/20 - Batch 230/435 - Loss: 1.2331, Acc: 0.6192
#   Epoch 3/20 - Batch 230/435 - Loss: 1.2331, Acc: 0.6192
#   Epoch 3/20 - Batch 240/435 - Loss: 1.2293, Acc: 0.6199
#   Epoch 3/20 - Batch 240/435 - Loss: 1.2293, Acc: 0.6199
#   Epoch 3/20 - Batch 250/435 - Loss: 1.2288, Acc: 0.6196
#   Epoch 3/20 - Batch 250/435 - Loss: 1.2288, Acc: 0.6196
#   Epoch 3/20 - Batch 260/435 - Loss: 1.2233, Acc: 0.6219
#   Epoch 3/20 - Batch 260/435 - Loss: 1.2233, Acc: 0.6219
#   Epoch 3/20 - Batch 270/435 - Loss: 1.2229, Acc: 0.6221
#   Epoch 3/20 - Batch 270/435 - Loss: 1.2229, Acc: 0.6221
#   Epoch 3/20 - Batch 280/435 - Loss: 1.2187, Acc: 0.6237
#   Epoch 3/20 - Batch 280/435 - Loss: 1.2187, Acc: 0.6237
#   Epoch 3/20 - Batch 290/435 - Loss: 1.2168, Acc: 0.6239
#   Epoch 3/20 - Batch 290/435 - Loss: 1.2168, Acc: 0.6239
#   Epoch 3/20 - Batch 300/435 - Loss: 1.2136, Acc: 0.6242
#   Epoch 3/20 - Batch 300/435 - Loss: 1.2136, Acc: 0.6242
#   Epoch 3/20 - Batch 310/435 - Loss: 1.2081, Acc: 0.6253
#   Epoch 3/20 - Batch 310/435 - Loss: 1.2081, Acc: 0.6253
#   Epoch 3/20 - Batch 320/435 - Loss: 1.2075, Acc: 0.6259
#   Epoch 3/20 - Batch 320/435 - Loss: 1.2075, Acc: 0.6259
#   Epoch 3/20 - Batch 330/435 - Loss: 1.2050, Acc: 0.6266
#   Epoch 3/20 - Batch 330/435 - Loss: 1.2050, Acc: 0.6266
#   Epoch 3/20 - Batch 340/435 - Loss: 1.2058, Acc: 0.6256
#   Epoch 3/20 - Batch 340/435 - Loss: 1.2058, Acc: 0.6256
#   Epoch 3/20 - Batch 350/435 - Loss: 1.2074, Acc: 0.6253
#   Epoch 3/20 - Batch 350/435 - Loss: 1.2074, Acc: 0.6253
#   Epoch 3/20 - Batch 360/435 - Loss: 1.2063, Acc: 0.6261
#   Epoch 3/20 - Batch 360/435 - Loss: 1.2063, Acc: 0.6261
#   Epoch 3/20 - Batch 370/435 - Loss: 1.2055, Acc: 0.6263
#   Epoch 3/20 - Batch 370/435 - Loss: 1.2055, Acc: 0.6263
#   Epoch 3/20 - Batch 380/435 - Loss: 1.2057, Acc: 0.6261
#   Epoch 3/20 - Batch 380/435 - Loss: 1.2057, Acc: 0.6261
#   Epoch 3/20 - Batch 390/435 - Loss: 1.2045, Acc: 0.6265
#   Epoch 3/20 - Batch 390/435 - Loss: 1.2045, Acc: 0.6265
#   Epoch 3/20 - Batch 400/435 - Loss: 1.2043, Acc: 0.6265
#   Epoch 3/20 - Batch 400/435 - Loss: 1.2043, Acc: 0.6265
#   Epoch 3/20 - Batch 410/435 - Loss: 1.2024, Acc: 0.6274
#   Epoch 3/20 - Batch 410/435 - Loss: 1.2024, Acc: 0.6274
#   Epoch 3/20 - Batch 420/435 - Loss: 1.2006, Acc: 0.6280
#   Epoch 3/20 - Batch 420/435 - Loss: 1.2006, Acc: 0.6280
#   Epoch 3/20 - Batch 430/435 - Loss: 1.1979, Acc: 0.6283
#   Epoch 3/20 - Batch 430/435 - Loss: 1.1979, Acc: 0.6283
# Epoch 3/20 (133.4s) - Train: Loss=1.1972, Acc=0.6286 | Val: Loss=1.1340, Acc=0.6313 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.6313
# Epoch 3/20 (133.4s) - Train: Loss=1.1972, Acc=0.6286 | Val: Loss=1.1340, Acc=0.6313 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.6313
#   Epoch 4/20 - Batch 10/435 - Loss: 1.0369, Acc: 0.6506
#   Epoch 4/20 - Batch 10/435 - Loss: 1.0369, Acc: 0.6506
#   Epoch 4/20 - Batch 20/435 - Loss: 1.0260, Acc: 0.6696
#   Epoch 4/20 - Batch 20/435 - Loss: 1.0260, Acc: 0.6696
#   Epoch 4/20 - Batch 30/435 - Loss: 1.0079, Acc: 0.6754
#   Epoch 4/20 - Batch 30/435 - Loss: 1.0079, Acc: 0.6754
#   Epoch 4/20 - Batch 40/435 - Loss: 0.9890, Acc: 0.6905
#   Epoch 4/20 - Batch 40/435 - Loss: 0.9890, Acc: 0.6905
#   Epoch 4/20 - Batch 50/435 - Loss: 0.9649, Acc: 0.7053
#   Epoch 4/20 - Batch 50/435 - Loss: 0.9649, Acc: 0.7053
#   Epoch 4/20 - Batch 60/435 - Loss: 0.9666, Acc: 0.7049
#   Epoch 4/20 - Batch 60/435 - Loss: 0.9666, Acc: 0.7049
#   Epoch 4/20 - Batch 70/435 - Loss: 0.9621, Acc: 0.7047
#   Epoch 4/20 - Batch 70/435 - Loss: 0.9621, Acc: 0.7047
#   Epoch 4/20 - Batch 80/435 - Loss: 0.9551, Acc: 0.7056
#   Epoch 4/20 - Batch 80/435 - Loss: 0.9551, Acc: 0.7056
#   Epoch 4/20 - Batch 90/435 - Loss: 0.9731, Acc: 0.6975
#   Epoch 4/20 - Batch 90/435 - Loss: 0.9731, Acc: 0.6975
#   Epoch 4/20 - Batch 100/435 - Loss: 0.9673, Acc: 0.6986
#   Epoch 4/20 - Batch 100/435 - Loss: 0.9673, Acc: 0.6986
#   Epoch 4/20 - Batch 110/435 - Loss: 0.9725, Acc: 0.6979
#   Epoch 4/20 - Batch 110/435 - Loss: 0.9725, Acc: 0.6979
#   Epoch 4/20 - Batch 120/435 - Loss: 0.9738, Acc: 0.6981
#   Epoch 4/20 - Batch 120/435 - Loss: 0.9738, Acc: 0.6981
#   Epoch 4/20 - Batch 130/435 - Loss: 0.9735, Acc: 0.6970
#   Epoch 4/20 - Batch 130/435 - Loss: 0.9735, Acc: 0.6970
#   Epoch 4/20 - Batch 140/435 - Loss: 0.9731, Acc: 0.6970
#   Epoch 4/20 - Batch 140/435 - Loss: 0.9731, Acc: 0.6970
#   Epoch 4/20 - Batch 150/435 - Loss: 0.9683, Acc: 0.6981
#   Epoch 4/20 - Batch 150/435 - Loss: 0.9683, Acc: 0.6981
#   Epoch 4/20 - Batch 160/435 - Loss: 0.9692, Acc: 0.6995
#   Epoch 4/20 - Batch 160/435 - Loss: 0.9692, Acc: 0.6995
#   Epoch 4/20 - Batch 170/435 - Loss: 0.9644, Acc: 0.7007
#   Epoch 4/20 - Batch 170/435 - Loss: 0.9644, Acc: 0.7007
#   Epoch 4/20 - Batch 180/435 - Loss: 0.9651, Acc: 0.7003
#   Epoch 4/20 - Batch 180/435 - Loss: 0.9651, Acc: 0.7003
#   Epoch 4/20 - Batch 190/435 - Loss: 0.9621, Acc: 0.6996
#   Epoch 4/20 - Batch 190/435 - Loss: 0.9621, Acc: 0.6996
#   Epoch 4/20 - Batch 200/435 - Loss: 0.9645, Acc: 0.7006
#   Epoch 4/20 - Batch 200/435 - Loss: 0.9645, Acc: 0.7006
#   Epoch 4/20 - Batch 210/435 - Loss: 0.9599, Acc: 0.7035
#   Epoch 4/20 - Batch 210/435 - Loss: 0.9599, Acc: 0.7035
#   Epoch 4/20 - Batch 220/435 - Loss: 0.9589, Acc: 0.7040
#   Epoch 4/20 - Batch 220/435 - Loss: 0.9589, Acc: 0.7040
#   Epoch 4/20 - Batch 230/435 - Loss: 0.9606, Acc: 0.7024
#   Epoch 4/20 - Batch 230/435 - Loss: 0.9606, Acc: 0.7024
#   Epoch 4/20 - Batch 240/435 - Loss: 0.9595, Acc: 0.7027
#   Epoch 4/20 - Batch 240/435 - Loss: 0.9595, Acc: 0.7027
#   Epoch 4/20 - Batch 250/435 - Loss: 0.9577, Acc: 0.7027
#   Epoch 4/20 - Batch 250/435 - Loss: 0.9577, Acc: 0.7027
#   Epoch 4/20 - Batch 260/435 - Loss: 0.9609, Acc: 0.7019
#   Epoch 4/20 - Batch 260/435 - Loss: 0.9609, Acc: 0.7019
#   Epoch 4/20 - Batch 270/435 - Loss: 0.9608, Acc: 0.7016
#   Epoch 4/20 - Batch 270/435 - Loss: 0.9608, Acc: 0.7016
#   Epoch 4/20 - Batch 280/435 - Loss: 0.9564, Acc: 0.7031
#   Epoch 4/20 - Batch 280/435 - Loss: 0.9564, Acc: 0.7031
#   Epoch 4/20 - Batch 290/435 - Loss: 0.9616, Acc: 0.7022
#   Epoch 4/20 - Batch 290/435 - Loss: 0.9616, Acc: 0.7022
#   Epoch 4/20 - Batch 300/435 - Loss: 0.9581, Acc: 0.7034
#   Epoch 4/20 - Batch 300/435 - Loss: 0.9581, Acc: 0.7034
#   Epoch 4/20 - Batch 310/435 - Loss: 0.9558, Acc: 0.7036
#   Epoch 4/20 - Batch 310/435 - Loss: 0.9558, Acc: 0.7036
#   Epoch 4/20 - Batch 320/435 - Loss: 0.9571, Acc: 0.7035
#   Epoch 4/20 - Batch 320/435 - Loss: 0.9571, Acc: 0.7035
#   Epoch 4/20 - Batch 330/435 - Loss: 0.9565, Acc: 0.7032
#   Epoch 4/20 - Batch 330/435 - Loss: 0.9565, Acc: 0.7032
#   Epoch 4/20 - Batch 340/435 - Loss: 0.9574, Acc: 0.7029
#   Epoch 4/20 - Batch 340/435 - Loss: 0.9574, Acc: 0.7029
#   Epoch 4/20 - Batch 350/435 - Loss: 0.9570, Acc: 0.7041
#   Epoch 4/20 - Batch 350/435 - Loss: 0.9570, Acc: 0.7041
#   Epoch 4/20 - Batch 360/435 - Loss: 0.9538, Acc: 0.7050
#   Epoch 4/20 - Batch 360/435 - Loss: 0.9538, Acc: 0.7050
#   Epoch 4/20 - Batch 370/435 - Loss: 0.9544, Acc: 0.7049
#   Epoch 4/20 - Batch 370/435 - Loss: 0.9544, Acc: 0.7049
#   Epoch 4/20 - Batch 380/435 - Loss: 0.9545, Acc: 0.7038
#   Epoch 4/20 - Batch 380/435 - Loss: 0.9545, Acc: 0.7038
#   Epoch 4/20 - Batch 390/435 - Loss: 0.9527, Acc: 0.7035
#   Epoch 4/20 - Batch 390/435 - Loss: 0.9527, Acc: 0.7035
#   Epoch 4/20 - Batch 400/435 - Loss: 0.9528, Acc: 0.7034
#   Epoch 4/20 - Batch 400/435 - Loss: 0.9528, Acc: 0.7034
#   Epoch 4/20 - Batch 410/435 - Loss: 0.9517, Acc: 0.7038
#   Epoch 4/20 - Batch 410/435 - Loss: 0.9517, Acc: 0.7038
#   Epoch 4/20 - Batch 420/435 - Loss: 0.9513, Acc: 0.7035
#   Epoch 4/20 - Batch 420/435 - Loss: 0.9513, Acc: 0.7035
#   Epoch 4/20 - Batch 430/435 - Loss: 0.9501, Acc: 0.7036
#   Epoch 4/20 - Batch 430/435 - Loss: 0.9501, Acc: 0.7036
# Epoch 4/20 (133.4s) - Train: Loss=0.9502, Acc=0.7038 | Val: Loss=1.0035, Acc=0.6908 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.6908
# Epoch 4/20 (133.4s) - Train: Loss=0.9502, Acc=0.7038 | Val: Loss=1.0035, Acc=0.6908 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.6908
#   Epoch 5/20 - Batch 10/435 - Loss: 0.9195, Acc: 0.7131
#   Epoch 5/20 - Batch 10/435 - Loss: 0.9195, Acc: 0.7131
#   Epoch 5/20 - Batch 20/435 - Loss: 0.8945, Acc: 0.7202
#   Epoch 5/20 - Batch 20/435 - Loss: 0.8945, Acc: 0.7202
#   Epoch 5/20 - Batch 30/435 - Loss: 0.8836, Acc: 0.7208
#   Epoch 5/20 - Batch 30/435 - Loss: 0.8836, Acc: 0.7208
#   Epoch 5/20 - Batch 40/435 - Loss: 0.8374, Acc: 0.7409
#   Epoch 5/20 - Batch 40/435 - Loss: 0.8374, Acc: 0.7409
#   Epoch 5/20 - Batch 50/435 - Loss: 0.8167, Acc: 0.7433
#   Epoch 5/20 - Batch 50/435 - Loss: 0.8167, Acc: 0.7433
#   Epoch 5/20 - Batch 60/435 - Loss: 0.8109, Acc: 0.7444
#   Epoch 5/20 - Batch 60/435 - Loss: 0.8109, Acc: 0.7444
#   Epoch 5/20 - Batch 70/435 - Loss: 0.7966, Acc: 0.7535
#   Epoch 5/20 - Batch 70/435 - Loss: 0.7966, Acc: 0.7535
#   Epoch 5/20 - Batch 80/435 - Loss: 0.7865, Acc: 0.7546
#   Epoch 5/20 - Batch 80/435 - Loss: 0.7865, Acc: 0.7546
#   Epoch 5/20 - Batch 90/435 - Loss: 0.7824, Acc: 0.7524
#   Epoch 5/20 - Batch 90/435 - Loss: 0.7824, Acc: 0.7524
#   Epoch 5/20 - Batch 100/435 - Loss: 0.7763, Acc: 0.7546
#   Epoch 5/20 - Batch 100/435 - Loss: 0.7763, Acc: 0.7546
#   Epoch 5/20 - Batch 110/435 - Loss: 0.7726, Acc: 0.7562
#   Epoch 5/20 - Batch 110/435 - Loss: 0.7726, Acc: 0.7562
#   Epoch 5/20 - Batch 120/435 - Loss: 0.7772, Acc: 0.7554
#   Epoch 5/20 - Batch 120/435 - Loss: 0.7772, Acc: 0.7554
#   Epoch 5/20 - Batch 130/435 - Loss: 0.7699, Acc: 0.7583
#   Epoch 5/20 - Batch 130/435 - Loss: 0.7699, Acc: 0.7583
#   Epoch 5/20 - Batch 140/435 - Loss: 0.7703, Acc: 0.7575
#   Epoch 5/20 - Batch 140/435 - Loss: 0.7703, Acc: 0.7575
#   Epoch 5/20 - Batch 150/435 - Loss: 0.7669, Acc: 0.7583
#   Epoch 5/20 - Batch 150/435 - Loss: 0.7669, Acc: 0.7583
#   Epoch 5/20 - Batch 160/435 - Loss: 0.7736, Acc: 0.7574
#   Epoch 5/20 - Batch 160/435 - Loss: 0.7736, Acc: 0.7574
#   Epoch 5/20 - Batch 170/435 - Loss: 0.7707, Acc: 0.7591
#   Epoch 5/20 - Batch 170/435 - Loss: 0.7707, Acc: 0.7591
#   Epoch 5/20 - Batch 180/435 - Loss: 0.7695, Acc: 0.7592
#   Epoch 5/20 - Batch 180/435 - Loss: 0.7695, Acc: 0.7592
#   Epoch 5/20 - Batch 190/435 - Loss: 0.7671, Acc: 0.7595
#   Epoch 5/20 - Batch 190/435 - Loss: 0.7671, Acc: 0.7595
#   Epoch 5/20 - Batch 200/435 - Loss: 0.7723, Acc: 0.7587
#   Epoch 5/20 - Batch 200/435 - Loss: 0.7723, Acc: 0.7587
#   Epoch 5/20 - Batch 210/435 - Loss: 0.7690, Acc: 0.7601
#   Epoch 5/20 - Batch 210/435 - Loss: 0.7690, Acc: 0.7601
#   Epoch 5/20 - Batch 220/435 - Loss: 0.7699, Acc: 0.7586
#   Epoch 5/20 - Batch 220/435 - Loss: 0.7699, Acc: 0.7586
#   Epoch 5/20 - Batch 230/435 - Loss: 0.7671, Acc: 0.7597
#   Epoch 5/20 - Batch 230/435 - Loss: 0.7671, Acc: 0.7597
#   Epoch 5/20 - Batch 240/435 - Loss: 0.7670, Acc: 0.7597
#   Epoch 5/20 - Batch 240/435 - Loss: 0.7670, Acc: 0.7597
#   Epoch 5/20 - Batch 250/435 - Loss: 0.7677, Acc: 0.7593
#   Epoch 5/20 - Batch 250/435 - Loss: 0.7677, Acc: 0.7593
#   Epoch 5/20 - Batch 260/435 - Loss: 0.7715, Acc: 0.7593
#   Epoch 5/20 - Batch 260/435 - Loss: 0.7715, Acc: 0.7593
#   Epoch 5/20 - Batch 270/435 - Loss: 0.7725, Acc: 0.7578
#   Epoch 5/20 - Batch 270/435 - Loss: 0.7725, Acc: 0.7578
#   Epoch 5/20 - Batch 280/435 - Loss: 0.7748, Acc: 0.7566
#   Epoch 5/20 - Batch 280/435 - Loss: 0.7748, Acc: 0.7566
#   Epoch 5/20 - Batch 290/435 - Loss: 0.7735, Acc: 0.7567
#   Epoch 5/20 - Batch 290/435 - Loss: 0.7735, Acc: 0.7567
#   Epoch 5/20 - Batch 300/435 - Loss: 0.7729, Acc: 0.7570
#   Epoch 5/20 - Batch 300/435 - Loss: 0.7729, Acc: 0.7570
#   Epoch 5/20 - Batch 310/435 - Loss: 0.7709, Acc: 0.7574
#   Epoch 5/20 - Batch 310/435 - Loss: 0.7709, Acc: 0.7574
#   Epoch 5/20 - Batch 320/435 - Loss: 0.7681, Acc: 0.7585
#   Epoch 5/20 - Batch 320/435 - Loss: 0.7681, Acc: 0.7585
#   Epoch 5/20 - Batch 330/435 - Loss: 0.7666, Acc: 0.7588
#   Epoch 5/20 - Batch 330/435 - Loss: 0.7666, Acc: 0.7588
#   Epoch 5/20 - Batch 340/435 - Loss: 0.7694, Acc: 0.7574
#   Epoch 5/20 - Batch 340/435 - Loss: 0.7694, Acc: 0.7574
#   Epoch 5/20 - Batch 350/435 - Loss: 0.7677, Acc: 0.7577
#   Epoch 5/20 - Batch 350/435 - Loss: 0.7677, Acc: 0.7577
#   Epoch 5/20 - Batch 360/435 - Loss: 0.7675, Acc: 0.7572
#   Epoch 5/20 - Batch 360/435 - Loss: 0.7675, Acc: 0.7572
#   Epoch 5/20 - Batch 370/435 - Loss: 0.7699, Acc: 0.7576
#   Epoch 5/20 - Batch 370/435 - Loss: 0.7699, Acc: 0.7576
#   Epoch 5/20 - Batch 380/435 - Loss: 0.7703, Acc: 0.7579
#   Epoch 5/20 - Batch 380/435 - Loss: 0.7703, Acc: 0.7579
#   Epoch 5/20 - Batch 390/435 - Loss: 0.7691, Acc: 0.7584
#   Epoch 5/20 - Batch 390/435 - Loss: 0.7691, Acc: 0.7584
#   Epoch 5/20 - Batch 400/435 - Loss: 0.7704, Acc: 0.7574
#   Epoch 5/20 - Batch 400/435 - Loss: 0.7704, Acc: 0.7574
#   Epoch 5/20 - Batch 410/435 - Loss: 0.7691, Acc: 0.7579
#   Epoch 5/20 - Batch 410/435 - Loss: 0.7691, Acc: 0.7579
#   Epoch 5/20 - Batch 420/435 - Loss: 0.7682, Acc: 0.7580
#   Epoch 5/20 - Batch 420/435 - Loss: 0.7682, Acc: 0.7580
#   Epoch 5/20 - Batch 430/435 - Loss: 0.7677, Acc: 0.7586
#   Epoch 5/20 - Batch 430/435 - Loss: 0.7677, Acc: 0.7586
# Epoch 5/20 (133.9s) - Train: Loss=0.7661, Acc=0.7588 | Val: Loss=0.9456, Acc=0.7109 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7109
# 💾 주기적 체크포인트 저장: epoch_005
# Epoch 5/20 (133.9s) - Train: Loss=0.7661, Acc=0.7588 | Val: Loss=0.9456, Acc=0.7109 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7109
# 💾 주기적 체크포인트 저장: epoch_005
#   Epoch 6/20 - Batch 10/435 - Loss: 0.5964, Acc: 0.8097
#   Epoch 6/20 - Batch 10/435 - Loss: 0.5964, Acc: 0.8097
#   Epoch 6/20 - Batch 20/435 - Loss: 0.6048, Acc: 0.8021
#   Epoch 6/20 - Batch 20/435 - Loss: 0.6048, Acc: 0.8021
#   Epoch 6/20 - Batch 30/435 - Loss: 0.6016, Acc: 0.8065
#   Epoch 6/20 - Batch 30/435 - Loss: 0.6016, Acc: 0.8065
#   Epoch 6/20 - Batch 40/435 - Loss: 0.5976, Acc: 0.8064
#   Epoch 6/20 - Batch 40/435 - Loss: 0.5976, Acc: 0.8064
#   Epoch 6/20 - Batch 50/435 - Loss: 0.6000, Acc: 0.8058
#   Epoch 6/20 - Batch 50/435 - Loss: 0.6000, Acc: 0.8058
#   Epoch 6/20 - Batch 60/435 - Loss: 0.5946, Acc: 0.8099
#   Epoch 6/20 - Batch 60/435 - Loss: 0.5946, Acc: 0.8099
#   Epoch 6/20 - Batch 70/435 - Loss: 0.6034, Acc: 0.8081
#   Epoch 6/20 - Batch 70/435 - Loss: 0.6034, Acc: 0.8081
#   Epoch 6/20 - Batch 80/435 - Loss: 0.6078, Acc: 0.8056
#   Epoch 6/20 - Batch 80/435 - Loss: 0.6078, Acc: 0.8056
#   Epoch 6/20 - Batch 90/435 - Loss: 0.6212, Acc: 0.8001
#   Epoch 6/20 - Batch 90/435 - Loss: 0.6212, Acc: 0.8001
#   Epoch 6/20 - Batch 100/435 - Loss: 0.6295, Acc: 0.7983
#   Epoch 6/20 - Batch 100/435 - Loss: 0.6295, Acc: 0.7983
#   Epoch 6/20 - Batch 110/435 - Loss: 0.6267, Acc: 0.7998
#   Epoch 6/20 - Batch 110/435 - Loss: 0.6267, Acc: 0.7998
#   Epoch 6/20 - Batch 120/435 - Loss: 0.6216, Acc: 0.8001
#   Epoch 6/20 - Batch 120/435 - Loss: 0.6216, Acc: 0.8001
#   Epoch 6/20 - Batch 130/435 - Loss: 0.6182, Acc: 0.8018
#   Epoch 6/20 - Batch 130/435 - Loss: 0.6182, Acc: 0.8018
#   Epoch 6/20 - Batch 140/435 - Loss: 0.6223, Acc: 0.8001
#   Epoch 6/20 - Batch 140/435 - Loss: 0.6223, Acc: 0.8001
#   Epoch 6/20 - Batch 150/435 - Loss: 0.6212, Acc: 0.7980
#   Epoch 6/20 - Batch 150/435 - Loss: 0.6212, Acc: 0.7980
#   Epoch 6/20 - Batch 160/435 - Loss: 0.6265, Acc: 0.7964
#   Epoch 6/20 - Batch 160/435 - Loss: 0.6265, Acc: 0.7964
#   Epoch 6/20 - Batch 170/435 - Loss: 0.6261, Acc: 0.7973
#   Epoch 6/20 - Batch 170/435 - Loss: 0.6261, Acc: 0.7973
#   Epoch 6/20 - Batch 180/435 - Loss: 0.6233, Acc: 0.8006
#   Epoch 6/20 - Batch 180/435 - Loss: 0.6233, Acc: 0.8006
#   Epoch 6/20 - Batch 190/435 - Loss: 0.6249, Acc: 0.8006
#   Epoch 6/20 - Batch 190/435 - Loss: 0.6249, Acc: 0.8006
#   Epoch 6/20 - Batch 200/435 - Loss: 0.6246, Acc: 0.8016
#   Epoch 6/20 - Batch 200/435 - Loss: 0.6246, Acc: 0.8016
#   Epoch 6/20 - Batch 210/435 - Loss: 0.6219, Acc: 0.8018
#   Epoch 6/20 - Batch 210/435 - Loss: 0.6219, Acc: 0.8018
#   Epoch 6/20 - Batch 220/435 - Loss: 0.6185, Acc: 0.8032
#   Epoch 6/20 - Batch 220/435 - Loss: 0.6185, Acc: 0.8032
#   Epoch 6/20 - Batch 230/435 - Loss: 0.6219, Acc: 0.8026
#   Epoch 6/20 - Batch 230/435 - Loss: 0.6219, Acc: 0.8026
#   Epoch 6/20 - Batch 240/435 - Loss: 0.6251, Acc: 0.8019
#   Epoch 6/20 - Batch 240/435 - Loss: 0.6251, Acc: 0.8019
#   Epoch 6/20 - Batch 250/435 - Loss: 0.6262, Acc: 0.8017
#   Epoch 6/20 - Batch 250/435 - Loss: 0.6262, Acc: 0.8017
#   Epoch 6/20 - Batch 260/435 - Loss: 0.6292, Acc: 0.8000
#   Epoch 6/20 - Batch 260/435 - Loss: 0.6292, Acc: 0.8000
#   Epoch 6/20 - Batch 270/435 - Loss: 0.6278, Acc: 0.8005
#   Epoch 6/20 - Batch 270/435 - Loss: 0.6278, Acc: 0.8005
#   Epoch 6/20 - Batch 280/435 - Loss: 0.6234, Acc: 0.8014
#   Epoch 6/20 - Batch 280/435 - Loss: 0.6234, Acc: 0.8014
#   Epoch 6/20 - Batch 290/435 - Loss: 0.6228, Acc: 0.8013
#   Epoch 6/20 - Batch 290/435 - Loss: 0.6228, Acc: 0.8013
#   Epoch 6/20 - Batch 300/435 - Loss: 0.6232, Acc: 0.8009
#   Epoch 6/20 - Batch 300/435 - Loss: 0.6232, Acc: 0.8009
#   Epoch 6/20 - Batch 310/435 - Loss: 0.6251, Acc: 0.8007
#   Epoch 6/20 - Batch 310/435 - Loss: 0.6251, Acc: 0.8007
#   Epoch 6/20 - Batch 320/435 - Loss: 0.6235, Acc: 0.8004
#   Epoch 6/20 - Batch 320/435 - Loss: 0.6235, Acc: 0.8004
#   Epoch 6/20 - Batch 330/435 - Loss: 0.6227, Acc: 0.8006
#   Epoch 6/20 - Batch 330/435 - Loss: 0.6227, Acc: 0.8006
#   Epoch 6/20 - Batch 340/435 - Loss: 0.6221, Acc: 0.8009
#   Epoch 6/20 - Batch 340/435 - Loss: 0.6221, Acc: 0.8009
#   Epoch 6/20 - Batch 350/435 - Loss: 0.6259, Acc: 0.7997
#   Epoch 6/20 - Batch 350/435 - Loss: 0.6259, Acc: 0.7997
#   Epoch 6/20 - Batch 360/435 - Loss: 0.6267, Acc: 0.7993
#   Epoch 6/20 - Batch 360/435 - Loss: 0.6267, Acc: 0.7993
#   Epoch 6/20 - Batch 370/435 - Loss: 0.6284, Acc: 0.7982
#   Epoch 6/20 - Batch 370/435 - Loss: 0.6284, Acc: 0.7982
#   Epoch 6/20 - Batch 380/435 - Loss: 0.6288, Acc: 0.7979
#   Epoch 6/20 - Batch 380/435 - Loss: 0.6288, Acc: 0.7979
#   Epoch 6/20 - Batch 390/435 - Loss: 0.6299, Acc: 0.7980
#   Epoch 6/20 - Batch 390/435 - Loss: 0.6299, Acc: 0.7980
#   Epoch 6/20 - Batch 400/435 - Loss: 0.6304, Acc: 0.7979
#   Epoch 6/20 - Batch 400/435 - Loss: 0.6304, Acc: 0.7979
#   Epoch 6/20 - Batch 410/435 - Loss: 0.6297, Acc: 0.7985
#   Epoch 6/20 - Batch 410/435 - Loss: 0.6297, Acc: 0.7985
#   Epoch 6/20 - Batch 420/435 - Loss: 0.6310, Acc: 0.7980
#   Epoch 6/20 - Batch 420/435 - Loss: 0.6310, Acc: 0.7980
#   Epoch 6/20 - Batch 430/435 - Loss: 0.6284, Acc: 0.7990
#   Epoch 6/20 - Batch 430/435 - Loss: 0.6284, Acc: 0.7990
# Epoch 6/20 (133.5s) - Train: Loss=0.6290, Acc=0.7987 | Val: Loss=0.8991, Acc=0.7290 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7290
# Epoch 6/20 (133.5s) - Train: Loss=0.6290, Acc=0.7987 | Val: Loss=0.8991, Acc=0.7290 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7290
#   Epoch 7/20 - Batch 10/435 - Loss: 0.4593, Acc: 0.8466
#   Epoch 7/20 - Batch 10/435 - Loss: 0.4593, Acc: 0.8466
#   Epoch 7/20 - Batch 20/435 - Loss: 0.4744, Acc: 0.8423
#   Epoch 7/20 - Batch 20/435 - Loss: 0.4744, Acc: 0.8423
#   Epoch 7/20 - Batch 30/435 - Loss: 0.4719, Acc: 0.8478
#   Epoch 7/20 - Batch 30/435 - Loss: 0.4719, Acc: 0.8478
#   Epoch 7/20 - Batch 40/435 - Loss: 0.4664, Acc: 0.8498
#   Epoch 7/20 - Batch 40/435 - Loss: 0.4664, Acc: 0.8498
#   Epoch 7/20 - Batch 50/435 - Loss: 0.4763, Acc: 0.8438
#   Epoch 7/20 - Batch 50/435 - Loss: 0.4763, Acc: 0.8438
#   Epoch 7/20 - Batch 60/435 - Loss: 0.4919, Acc: 0.8386
#   Epoch 7/20 - Batch 60/435 - Loss: 0.4919, Acc: 0.8386
#   Epoch 7/20 - Batch 70/435 - Loss: 0.4910, Acc: 0.8371
#   Epoch 7/20 - Batch 70/435 - Loss: 0.4910, Acc: 0.8371
#   Epoch 7/20 - Batch 80/435 - Loss: 0.4786, Acc: 0.8414
#   Epoch 7/20 - Batch 80/435 - Loss: 0.4786, Acc: 0.8414
#   Epoch 7/20 - Batch 90/435 - Loss: 0.4863, Acc: 0.8403
#   Epoch 7/20 - Batch 90/435 - Loss: 0.4863, Acc: 0.8403
#   Epoch 7/20 - Batch 100/435 - Loss: 0.4883, Acc: 0.8403
#   Epoch 7/20 - Batch 100/435 - Loss: 0.4883, Acc: 0.8403
#   Epoch 7/20 - Batch 110/435 - Loss: 0.4893, Acc: 0.8415
#   Epoch 7/20 - Batch 110/435 - Loss: 0.4893, Acc: 0.8415
#   Epoch 7/20 - Batch 120/435 - Loss: 0.4963, Acc: 0.8386
#   Epoch 7/20 - Batch 120/435 - Loss: 0.4963, Acc: 0.8386
#   Epoch 7/20 - Batch 130/435 - Loss: 0.4969, Acc: 0.8366
#   Epoch 7/20 - Batch 130/435 - Loss: 0.4969, Acc: 0.8366
#   Epoch 7/20 - Batch 140/435 - Loss: 0.5079, Acc: 0.8336
#   Epoch 7/20 - Batch 140/435 - Loss: 0.5079, Acc: 0.8336
#   Epoch 7/20 - Batch 150/435 - Loss: 0.5017, Acc: 0.8363
#   Epoch 7/20 - Batch 150/435 - Loss: 0.5017, Acc: 0.8363
#   Epoch 7/20 - Batch 160/435 - Loss: 0.5031, Acc: 0.8360
#   Epoch 7/20 - Batch 160/435 - Loss: 0.5031, Acc: 0.8360
#   Epoch 7/20 - Batch 170/435 - Loss: 0.5010, Acc: 0.8368
#   Epoch 7/20 - Batch 170/435 - Loss: 0.5010, Acc: 0.8368
#   Epoch 7/20 - Batch 180/435 - Loss: 0.5013, Acc: 0.8368
#   Epoch 7/20 - Batch 180/435 - Loss: 0.5013, Acc: 0.8368
#   Epoch 7/20 - Batch 190/435 - Loss: 0.5031, Acc: 0.8359
#   Epoch 7/20 - Batch 190/435 - Loss: 0.5031, Acc: 0.8359
#   Epoch 7/20 - Batch 200/435 - Loss: 0.5000, Acc: 0.8374
#   Epoch 7/20 - Batch 200/435 - Loss: 0.5000, Acc: 0.8374
#   Epoch 7/20 - Batch 210/435 - Loss: 0.5006, Acc: 0.8375
#   Epoch 7/20 - Batch 210/435 - Loss: 0.5006, Acc: 0.8375
#   Epoch 7/20 - Batch 220/435 - Loss: 0.4994, Acc: 0.8381
#   Epoch 7/20 - Batch 220/435 - Loss: 0.4994, Acc: 0.8381
#   Epoch 7/20 - Batch 230/435 - Loss: 0.5003, Acc: 0.8373
#   Epoch 7/20 - Batch 230/435 - Loss: 0.5003, Acc: 0.8373
#   Epoch 7/20 - Batch 240/435 - Loss: 0.5020, Acc: 0.8371
#   Epoch 7/20 - Batch 240/435 - Loss: 0.5020, Acc: 0.8371
#   Epoch 7/20 - Batch 250/435 - Loss: 0.5039, Acc: 0.8365
#   Epoch 7/20 - Batch 250/435 - Loss: 0.5039, Acc: 0.8365
#   Epoch 7/20 - Batch 260/435 - Loss: 0.5001, Acc: 0.8378
#   Epoch 7/20 - Batch 260/435 - Loss: 0.5001, Acc: 0.8378
#   Epoch 7/20 - Batch 270/435 - Loss: 0.5020, Acc: 0.8366
#   Epoch 7/20 - Batch 270/435 - Loss: 0.5020, Acc: 0.8366
#   Epoch 7/20 - Batch 280/435 - Loss: 0.5022, Acc: 0.8371
#   Epoch 7/20 - Batch 280/435 - Loss: 0.5022, Acc: 0.8371
#   Epoch 7/20 - Batch 290/435 - Loss: 0.5035, Acc: 0.8364
#   Epoch 7/20 - Batch 290/435 - Loss: 0.5035, Acc: 0.8364
#   Epoch 7/20 - Batch 300/435 - Loss: 0.5055, Acc: 0.8359
#   Epoch 7/20 - Batch 300/435 - Loss: 0.5055, Acc: 0.8359
#   Epoch 7/20 - Batch 310/435 - Loss: 0.5056, Acc: 0.8359
#   Epoch 7/20 - Batch 310/435 - Loss: 0.5056, Acc: 0.8359
#   Epoch 7/20 - Batch 320/435 - Loss: 0.5061, Acc: 0.8357
#   Epoch 7/20 - Batch 320/435 - Loss: 0.5061, Acc: 0.8357
#   Epoch 7/20 - Batch 330/435 - Loss: 0.5036, Acc: 0.8357
#   Epoch 7/20 - Batch 330/435 - Loss: 0.5036, Acc: 0.8357
#   Epoch 7/20 - Batch 340/435 - Loss: 0.5053, Acc: 0.8349
#   Epoch 7/20 - Batch 340/435 - Loss: 0.5053, Acc: 0.8349
#   Epoch 7/20 - Batch 350/435 - Loss: 0.5049, Acc: 0.8352
#   Epoch 7/20 - Batch 350/435 - Loss: 0.5049, Acc: 0.8352
#   Epoch 7/20 - Batch 360/435 - Loss: 0.5027, Acc: 0.8364
#   Epoch 7/20 - Batch 360/435 - Loss: 0.5027, Acc: 0.8364
#   Epoch 7/20 - Batch 370/435 - Loss: 0.5045, Acc: 0.8352
#   Epoch 7/20 - Batch 370/435 - Loss: 0.5045, Acc: 0.8352
#   Epoch 7/20 - Batch 380/435 - Loss: 0.5048, Acc: 0.8352
#   Epoch 7/20 - Batch 380/435 - Loss: 0.5048, Acc: 0.8352
#   Epoch 7/20 - Batch 390/435 - Loss: 0.5047, Acc: 0.8350
#   Epoch 7/20 - Batch 390/435 - Loss: 0.5047, Acc: 0.8350
#   Epoch 7/20 - Batch 400/435 - Loss: 0.5070, Acc: 0.8348
#   Epoch 7/20 - Batch 400/435 - Loss: 0.5070, Acc: 0.8348
#   Epoch 7/20 - Batch 410/435 - Loss: 0.5067, Acc: 0.8346
#   Epoch 7/20 - Batch 410/435 - Loss: 0.5067, Acc: 0.8346
#   Epoch 7/20 - Batch 420/435 - Loss: 0.5090, Acc: 0.8343
#   Epoch 7/20 - Batch 420/435 - Loss: 0.5090, Acc: 0.8343
#   Epoch 7/20 - Batch 430/435 - Loss: 0.5087, Acc: 0.8341
#   Epoch 7/20 - Batch 430/435 - Loss: 0.5087, Acc: 0.8341
# Epoch 7/20 (133.5s) - Train: Loss=0.5089, Acc=0.8340 | Val: Loss=0.9032, Acc=0.7406 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7406
# Epoch 7/20 (133.5s) - Train: Loss=0.5089, Acc=0.8340 | Val: Loss=0.9032, Acc=0.7406 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7406
#   Epoch 8/20 - Batch 10/435 - Loss: 0.4368, Acc: 0.8636
#   Epoch 8/20 - Batch 10/435 - Loss: 0.4368, Acc: 0.8636
#   Epoch 8/20 - Batch 20/435 - Loss: 0.4271, Acc: 0.8646
#   Epoch 8/20 - Batch 20/435 - Loss: 0.4271, Acc: 0.8646
#   Epoch 8/20 - Batch 30/435 - Loss: 0.4244, Acc: 0.8599
#   Epoch 8/20 - Batch 30/435 - Loss: 0.4244, Acc: 0.8599
#   Epoch 8/20 - Batch 40/435 - Loss: 0.4323, Acc: 0.8529
#   Epoch 8/20 - Batch 40/435 - Loss: 0.4323, Acc: 0.8529
#   Epoch 8/20 - Batch 50/435 - Loss: 0.4202, Acc: 0.8591
#   Epoch 8/20 - Batch 50/435 - Loss: 0.4202, Acc: 0.8591
#   Epoch 8/20 - Batch 60/435 - Loss: 0.4238, Acc: 0.8607
#   Epoch 8/20 - Batch 60/435 - Loss: 0.4238, Acc: 0.8607
#   Epoch 8/20 - Batch 70/435 - Loss: 0.4224, Acc: 0.8609
#   Epoch 8/20 - Batch 70/435 - Loss: 0.4224, Acc: 0.8609
#   Epoch 8/20 - Batch 80/435 - Loss: 0.4185, Acc: 0.8634
#   Epoch 8/20 - Batch 80/435 - Loss: 0.4185, Acc: 0.8634
#   Epoch 8/20 - Batch 90/435 - Loss: 0.4170, Acc: 0.8609
#   Epoch 8/20 - Batch 90/435 - Loss: 0.4170, Acc: 0.8609
#   Epoch 8/20 - Batch 100/435 - Loss: 0.4208, Acc: 0.8601
#   Epoch 8/20 - Batch 100/435 - Loss: 0.4208, Acc: 0.8601
#   Epoch 8/20 - Batch 110/435 - Loss: 0.4239, Acc: 0.8598
#   Epoch 8/20 - Batch 110/435 - Loss: 0.4239, Acc: 0.8598
#   Epoch 8/20 - Batch 120/435 - Loss: 0.4255, Acc: 0.8595
#   Epoch 8/20 - Batch 120/435 - Loss: 0.4255, Acc: 0.8595
#   Epoch 8/20 - Batch 130/435 - Loss: 0.4222, Acc: 0.8612
#   Epoch 8/20 - Batch 130/435 - Loss: 0.4222, Acc: 0.8612
#   Epoch 8/20 - Batch 140/435 - Loss: 0.4240, Acc: 0.8604
#   Epoch 8/20 - Batch 140/435 - Loss: 0.4240, Acc: 0.8604
#   Epoch 8/20 - Batch 150/435 - Loss: 0.4216, Acc: 0.8609
#   Epoch 8/20 - Batch 150/435 - Loss: 0.4216, Acc: 0.8609
#   Epoch 8/20 - Batch 160/435 - Loss: 0.4190, Acc: 0.8624
#   Epoch 8/20 - Batch 160/435 - Loss: 0.4190, Acc: 0.8624
#   Epoch 8/20 - Batch 170/435 - Loss: 0.4225, Acc: 0.8620
#   Epoch 8/20 - Batch 170/435 - Loss: 0.4225, Acc: 0.8620
#   Epoch 8/20 - Batch 180/435 - Loss: 0.4214, Acc: 0.8626
#   Epoch 8/20 - Batch 180/435 - Loss: 0.4214, Acc: 0.8626
#   Epoch 8/20 - Batch 190/435 - Loss: 0.4167, Acc: 0.8644
#   Epoch 8/20 - Batch 190/435 - Loss: 0.4167, Acc: 0.8644
#   Epoch 8/20 - Batch 200/435 - Loss: 0.4177, Acc: 0.8633
#   Epoch 8/20 - Batch 200/435 - Loss: 0.4177, Acc: 0.8633
#   Epoch 8/20 - Batch 210/435 - Loss: 0.4166, Acc: 0.8621
#   Epoch 8/20 - Batch 210/435 - Loss: 0.4166, Acc: 0.8621
#   Epoch 8/20 - Batch 220/435 - Loss: 0.4160, Acc: 0.8628
#   Epoch 8/20 - Batch 220/435 - Loss: 0.4160, Acc: 0.8628
#   Epoch 8/20 - Batch 230/435 - Loss: 0.4117, Acc: 0.8649
#   Epoch 8/20 - Batch 230/435 - Loss: 0.4117, Acc: 0.8649
#   Epoch 8/20 - Batch 240/435 - Loss: 0.4131, Acc: 0.8642
#   Epoch 8/20 - Batch 240/435 - Loss: 0.4131, Acc: 0.8642
#   Epoch 8/20 - Batch 250/435 - Loss: 0.4129, Acc: 0.8640
#   Epoch 8/20 - Batch 250/435 - Loss: 0.4129, Acc: 0.8640
#   Epoch 8/20 - Batch 260/435 - Loss: 0.4145, Acc: 0.8634
#   Epoch 8/20 - Batch 260/435 - Loss: 0.4145, Acc: 0.8634
#   Epoch 8/20 - Batch 270/435 - Loss: 0.4128, Acc: 0.8636
#   Epoch 8/20 - Batch 270/435 - Loss: 0.4128, Acc: 0.8636
#   Epoch 8/20 - Batch 280/435 - Loss: 0.4123, Acc: 0.8640
#   Epoch 8/20 - Batch 280/435 - Loss: 0.4123, Acc: 0.8640
#   Epoch 8/20 - Batch 290/435 - Loss: 0.4128, Acc: 0.8639
#   Epoch 8/20 - Batch 290/435 - Loss: 0.4128, Acc: 0.8639
#   Epoch 8/20 - Batch 300/435 - Loss: 0.4144, Acc: 0.8633
#   Epoch 8/20 - Batch 300/435 - Loss: 0.4144, Acc: 0.8633
#   Epoch 8/20 - Batch 310/435 - Loss: 0.4144, Acc: 0.8628
#   Epoch 8/20 - Batch 310/435 - Loss: 0.4144, Acc: 0.8628
#   Epoch 8/20 - Batch 320/435 - Loss: 0.4118, Acc: 0.8637
#   Epoch 8/20 - Batch 320/435 - Loss: 0.4118, Acc: 0.8637
#   Epoch 8/20 - Batch 330/435 - Loss: 0.4108, Acc: 0.8646
#   Epoch 8/20 - Batch 330/435 - Loss: 0.4108, Acc: 0.8646
#   Epoch 8/20 - Batch 340/435 - Loss: 0.4078, Acc: 0.8660
#   Epoch 8/20 - Batch 340/435 - Loss: 0.4078, Acc: 0.8660
#   Epoch 8/20 - Batch 350/435 - Loss: 0.4081, Acc: 0.8656
#   Epoch 8/20 - Batch 350/435 - Loss: 0.4081, Acc: 0.8656
#   Epoch 8/20 - Batch 360/435 - Loss: 0.4078, Acc: 0.8659
#   Epoch 8/20 - Batch 360/435 - Loss: 0.4078, Acc: 0.8659
#   Epoch 8/20 - Batch 370/435 - Loss: 0.4112, Acc: 0.8652
#   Epoch 8/20 - Batch 370/435 - Loss: 0.4112, Acc: 0.8652
#   Epoch 8/20 - Batch 380/435 - Loss: 0.4091, Acc: 0.8658
#   Epoch 8/20 - Batch 380/435 - Loss: 0.4091, Acc: 0.8658
#   Epoch 8/20 - Batch 390/435 - Loss: 0.4096, Acc: 0.8652
#   Epoch 8/20 - Batch 390/435 - Loss: 0.4096, Acc: 0.8652
#   Epoch 8/20 - Batch 400/435 - Loss: 0.4092, Acc: 0.8652
#   Epoch 8/20 - Batch 400/435 - Loss: 0.4092, Acc: 0.8652
#   Epoch 8/20 - Batch 410/435 - Loss: 0.4115, Acc: 0.8642
#   Epoch 8/20 - Batch 410/435 - Loss: 0.4115, Acc: 0.8642
#   Epoch 8/20 - Batch 420/435 - Loss: 0.4124, Acc: 0.8640
#   Epoch 8/20 - Batch 420/435 - Loss: 0.4124, Acc: 0.8640
#   Epoch 8/20 - Batch 430/435 - Loss: 0.4106, Acc: 0.8647
#   Epoch 8/20 - Batch 430/435 - Loss: 0.4106, Acc: 0.8647
# Epoch 8/20 (133.7s) - Train: Loss=0.4111, Acc=0.8647 | Val: Loss=0.8915, Acc=0.7451 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7451
# Epoch 8/20 (133.7s) - Train: Loss=0.4111, Acc=0.8647 | Val: Loss=0.8915, Acc=0.7451 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7451
#   Epoch 9/20 - Batch 10/435 - Loss: 0.3487, Acc: 0.8722
#   Epoch 9/20 - Batch 10/435 - Loss: 0.3487, Acc: 0.8722
#   Epoch 9/20 - Batch 20/435 - Loss: 0.3582, Acc: 0.8720
#   Epoch 9/20 - Batch 20/435 - Loss: 0.3582, Acc: 0.8720
#   Epoch 9/20 - Batch 30/435 - Loss: 0.3470, Acc: 0.8780
#   Epoch 9/20 - Batch 30/435 - Loss: 0.3470, Acc: 0.8780
#   Epoch 9/20 - Batch 40/435 - Loss: 0.3526, Acc: 0.8780
#   Epoch 9/20 - Batch 40/435 - Loss: 0.3526, Acc: 0.8780
#   Epoch 9/20 - Batch 50/435 - Loss: 0.3413, Acc: 0.8830
#   Epoch 9/20 - Batch 50/435 - Loss: 0.3413, Acc: 0.8830
#   Epoch 9/20 - Batch 60/435 - Loss: 0.3506, Acc: 0.8786
#   Epoch 9/20 - Batch 60/435 - Loss: 0.3506, Acc: 0.8786
#   Epoch 9/20 - Batch 70/435 - Loss: 0.3396, Acc: 0.8838
#   Epoch 9/20 - Batch 70/435 - Loss: 0.3396, Acc: 0.8838
#   Epoch 9/20 - Batch 80/435 - Loss: 0.3468, Acc: 0.8835
#   Epoch 9/20 - Batch 80/435 - Loss: 0.3468, Acc: 0.8835
#   Epoch 9/20 - Batch 90/435 - Loss: 0.3439, Acc: 0.8870
#   Epoch 9/20 - Batch 90/435 - Loss: 0.3439, Acc: 0.8870
#   Epoch 9/20 - Batch 100/435 - Loss: 0.3388, Acc: 0.8880
#   Epoch 9/20 - Batch 100/435 - Loss: 0.3388, Acc: 0.8880
#   Epoch 9/20 - Batch 110/435 - Loss: 0.3420, Acc: 0.8880
#   Epoch 9/20 - Batch 110/435 - Loss: 0.3420, Acc: 0.8880
#   Epoch 9/20 - Batch 120/435 - Loss: 0.3352, Acc: 0.8905
#   Epoch 9/20 - Batch 120/435 - Loss: 0.3352, Acc: 0.8905
#   Epoch 9/20 - Batch 130/435 - Loss: 0.3380, Acc: 0.8910
#   Epoch 9/20 - Batch 130/435 - Loss: 0.3380, Acc: 0.8910
#   Epoch 9/20 - Batch 140/435 - Loss: 0.3382, Acc: 0.8898
#   Epoch 9/20 - Batch 140/435 - Loss: 0.3382, Acc: 0.8898
#   Epoch 9/20 - Batch 150/435 - Loss: 0.3384, Acc: 0.8893
#   Epoch 9/20 - Batch 150/435 - Loss: 0.3384, Acc: 0.8893
#   Epoch 9/20 - Batch 160/435 - Loss: 0.3377, Acc: 0.8901
#   Epoch 9/20 - Batch 160/435 - Loss: 0.3377, Acc: 0.8901
#   Epoch 9/20 - Batch 170/435 - Loss: 0.3384, Acc: 0.8893
#   Epoch 9/20 - Batch 170/435 - Loss: 0.3384, Acc: 0.8893
#   Epoch 9/20 - Batch 180/435 - Loss: 0.3409, Acc: 0.8897
#   Epoch 9/20 - Batch 180/435 - Loss: 0.3409, Acc: 0.8897
#   Epoch 9/20 - Batch 190/435 - Loss: 0.3415, Acc: 0.8887
#   Epoch 9/20 - Batch 190/435 - Loss: 0.3415, Acc: 0.8887
#   Epoch 9/20 - Batch 200/435 - Loss: 0.3415, Acc: 0.8882
#   Epoch 9/20 - Batch 200/435 - Loss: 0.3415, Acc: 0.8882
#   Epoch 9/20 - Batch 210/435 - Loss: 0.3372, Acc: 0.8895
#   Epoch 9/20 - Batch 210/435 - Loss: 0.3372, Acc: 0.8895
#   Epoch 9/20 - Batch 220/435 - Loss: 0.3363, Acc: 0.8893
#   Epoch 9/20 - Batch 220/435 - Loss: 0.3363, Acc: 0.8893
#   Epoch 9/20 - Batch 230/435 - Loss: 0.3400, Acc: 0.8887
#   Epoch 9/20 - Batch 230/435 - Loss: 0.3400, Acc: 0.8887
#   Epoch 9/20 - Batch 240/435 - Loss: 0.3389, Acc: 0.8882
#   Epoch 9/20 - Batch 240/435 - Loss: 0.3389, Acc: 0.8882
#   Epoch 9/20 - Batch 250/435 - Loss: 0.3391, Acc: 0.8877
#   Epoch 9/20 - Batch 250/435 - Loss: 0.3391, Acc: 0.8877
#   Epoch 9/20 - Batch 260/435 - Loss: 0.3382, Acc: 0.8878
#   Epoch 9/20 - Batch 260/435 - Loss: 0.3382, Acc: 0.8878
#   Epoch 9/20 - Batch 270/435 - Loss: 0.3400, Acc: 0.8871
#   Epoch 9/20 - Batch 270/435 - Loss: 0.3400, Acc: 0.8871
#   Epoch 9/20 - Batch 280/435 - Loss: 0.3418, Acc: 0.8867
#   Epoch 9/20 - Batch 280/435 - Loss: 0.3418, Acc: 0.8867
#   Epoch 9/20 - Batch 290/435 - Loss: 0.3421, Acc: 0.8865
#   Epoch 9/20 - Batch 290/435 - Loss: 0.3421, Acc: 0.8865
#   Epoch 9/20 - Batch 300/435 - Loss: 0.3436, Acc: 0.8865
#   Epoch 9/20 - Batch 300/435 - Loss: 0.3436, Acc: 0.8865
#   Epoch 9/20 - Batch 310/435 - Loss: 0.3429, Acc: 0.8869
#   Epoch 9/20 - Batch 310/435 - Loss: 0.3429, Acc: 0.8869
#   Epoch 9/20 - Batch 320/435 - Loss: 0.3436, Acc: 0.8867
#   Epoch 9/20 - Batch 320/435 - Loss: 0.3436, Acc: 0.8867
#   Epoch 9/20 - Batch 330/435 - Loss: 0.3439, Acc: 0.8862
#   Epoch 9/20 - Batch 330/435 - Loss: 0.3439, Acc: 0.8862
#   Epoch 9/20 - Batch 340/435 - Loss: 0.3438, Acc: 0.8860
#   Epoch 9/20 - Batch 340/435 - Loss: 0.3438, Acc: 0.8860
#   Epoch 9/20 - Batch 350/435 - Loss: 0.3429, Acc: 0.8860
#   Epoch 9/20 - Batch 350/435 - Loss: 0.3429, Acc: 0.8860
#   Epoch 9/20 - Batch 360/435 - Loss: 0.3446, Acc: 0.8862
#   Epoch 9/20 - Batch 360/435 - Loss: 0.3446, Acc: 0.8862
#   Epoch 9/20 - Batch 370/435 - Loss: 0.3459, Acc: 0.8854
#   Epoch 9/20 - Batch 370/435 - Loss: 0.3459, Acc: 0.8854
#   Epoch 9/20 - Batch 380/435 - Loss: 0.3475, Acc: 0.8852
#   Epoch 9/20 - Batch 380/435 - Loss: 0.3475, Acc: 0.8852
#   Epoch 9/20 - Batch 390/435 - Loss: 0.3481, Acc: 0.8849
#   Epoch 9/20 - Batch 390/435 - Loss: 0.3481, Acc: 0.8849
#   Epoch 9/20 - Batch 400/435 - Loss: 0.3479, Acc: 0.8852
#   Epoch 9/20 - Batch 400/435 - Loss: 0.3479, Acc: 0.8852
#   Epoch 9/20 - Batch 410/435 - Loss: 0.3470, Acc: 0.8853
#   Epoch 9/20 - Batch 410/435 - Loss: 0.3470, Acc: 0.8853
#   Epoch 9/20 - Batch 420/435 - Loss: 0.3480, Acc: 0.8854
#   Epoch 9/20 - Batch 420/435 - Loss: 0.3480, Acc: 0.8854
#   Epoch 9/20 - Batch 430/435 - Loss: 0.3488, Acc: 0.8850
#   Epoch 9/20 - Batch 430/435 - Loss: 0.3488, Acc: 0.8850
# Epoch 9/20 (133.8s) - Train: Loss=0.3493, Acc=0.8847 | Val: Loss=0.8924, Acc=0.7529 | LR=1.00e-04
# Epoch 9/20 (133.8s) - Train: Loss=0.3493, Acc=0.8847 | Val: Loss=0.8924, Acc=0.7529 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7529
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7529
#   Epoch 10/20 - Batch 10/435 - Loss: 0.3255, Acc: 0.9062
#   Epoch 10/20 - Batch 10/435 - Loss: 0.3255, Acc: 0.9062
#   Epoch 10/20 - Batch 20/435 - Loss: 0.2897, Acc: 0.9137
#   Epoch 10/20 - Batch 20/435 - Loss: 0.2897, Acc: 0.9137
#   Epoch 10/20 - Batch 30/435 - Loss: 0.2796, Acc: 0.9173
#   Epoch 10/20 - Batch 30/435 - Loss: 0.2796, Acc: 0.9173
#   Epoch 10/20 - Batch 40/435 - Loss: 0.2757, Acc: 0.9154
#   Epoch 10/20 - Batch 40/435 - Loss: 0.2757, Acc: 0.9154
#   Epoch 10/20 - Batch 50/435 - Loss: 0.2844, Acc: 0.9112
#   Epoch 10/20 - Batch 50/435 - Loss: 0.2844, Acc: 0.9112
#   Epoch 10/20 - Batch 60/435 - Loss: 0.2899, Acc: 0.9083
#   Epoch 10/20 - Batch 60/435 - Loss: 0.2899, Acc: 0.9083
#   Epoch 10/20 - Batch 70/435 - Loss: 0.2927, Acc: 0.9049
#   Epoch 10/20 - Batch 70/435 - Loss: 0.2927, Acc: 0.9049
#   Epoch 10/20 - Batch 80/435 - Loss: 0.2914, Acc: 0.9062
#   Epoch 10/20 - Batch 80/435 - Loss: 0.2914, Acc: 0.9062
#   Epoch 10/20 - Batch 90/435 - Loss: 0.2944, Acc: 0.9045
#   Epoch 10/20 - Batch 90/435 - Loss: 0.2944, Acc: 0.9045
#   Epoch 10/20 - Batch 100/435 - Loss: 0.2937, Acc: 0.9056
#   Epoch 10/20 - Batch 100/435 - Loss: 0.2937, Acc: 0.9056
#   Epoch 10/20 - Batch 110/435 - Loss: 0.2924, Acc: 0.9071
#   Epoch 10/20 - Batch 110/435 - Loss: 0.2924, Acc: 0.9071
#   Epoch 10/20 - Batch 120/435 - Loss: 0.2928, Acc: 0.9070
#   Epoch 10/20 - Batch 120/435 - Loss: 0.2928, Acc: 0.9070
#   Epoch 10/20 - Batch 130/435 - Loss: 0.2910, Acc: 0.9072
# ...
# ⚠️ Early stopping counter: 2/5
#   Epoch 18/20 - Batch 10/435 - Loss: 0.0989, Acc: 0.9631
#   Epoch 18/20 - Batch 10/435 - Loss: 0.0989, Acc: 0.9631
#   Epoch 18/20 - Batch 20/435 - Loss: 0.1164, Acc: 0.9568
#   Epoch 18/20 - Batch 20/435 - Loss: 0.1164, Acc: 0.9568
#   Epoch 18/20 - Batch 30/435 - Loss: 0.1132, Acc: 0.9607
#   Epoch 18/20 - Batch 30/435 - Loss: 0.1132, Acc: 0.9607
#   Epoch 18/20 - Batch 40/435 - Loss: 0.1113, Acc: 0.9634
#   Epoch 18/20 - Batch 40/435 - Loss: 0.1113, Acc: 0.9634
#   Epoch 18/20 - Batch 50/435 - Loss: 0.1200, Acc: 0.9602
#   Epoch 18/20 - Batch 50/435 - Loss: 0.1200, Acc: 0.9602
#   Epoch 18/20 - Batch 60/435 - Loss: 0.1247, Acc: 0.9565
#   Epoch 18/20 - Batch 60/435 - Loss: 0.1247, Acc: 0.9565
#   Epoch 18/20 - Batch 70/435 - Loss: 0.1238, Acc: 0.9555
#   Epoch 18/20 - Batch 70/435 - Loss: 0.1238, Acc: 0.9555
#   Epoch 18/20 - Batch 80/435 - Loss: 0.1254, Acc: 0.9552
#   Epoch 18/20 - Batch 80/435 - Loss: 0.1254, Acc: 0.9552
#   Epoch 18/20 - Batch 90/435 - Loss: 0.1283, Acc: 0.9550
#   Epoch 18/20 - Batch 90/435 - Loss: 0.1283, Acc: 0.9550
#   Epoch 18/20 - Batch 100/435 - Loss: 0.1277, Acc: 0.9548
#   Epoch 18/20 - Batch 100/435 - Loss: 0.1277, Acc: 0.9548
#   Epoch 18/20 - Batch 110/435 - Loss: 0.1284, Acc: 0.9550
#   Epoch 18/20 - Batch 110/435 - Loss: 0.1284, Acc: 0.9550
#   Epoch 18/20 - Batch 120/435 - Loss: 0.1259, Acc: 0.9553
#   Epoch 18/20 - Batch 120/435 - Loss: 0.1259, Acc: 0.9553
#   Epoch 18/20 - Batch 130/435 - Loss: 0.1260, Acc: 0.9556
#   Epoch 18/20 - Batch 130/435 - Loss: 0.1260, Acc: 0.9556
#   Epoch 18/20 - Batch 140/435 - Loss: 0.1270, Acc: 0.9568
#   Epoch 18/20 - Batch 140/435 - Loss: 0.1270, Acc: 0.9568
#   Epoch 18/20 - Batch 150/435 - Loss: 0.1270, Acc: 0.9576
#   Epoch 18/20 - Batch 150/435 - Loss: 0.1270, Acc: 0.9576
#   Epoch 18/20 - Batch 160/435 - Loss: 0.1306, Acc: 0.9575
#   Epoch 18/20 - Batch 160/435 - Loss: 0.1306, Acc: 0.9575
#   Epoch 18/20 - Batch 170/435 - Loss: 0.1317, Acc: 0.9576
#   Epoch 18/20 - Batch 170/435 - Loss: 0.1317, Acc: 0.9576
#   Epoch 18/20 - Batch 180/435 - Loss: 0.1345, Acc: 0.9561
#   Epoch 18/20 - Batch 180/435 - Loss: 0.1345, Acc: 0.9561
#   Epoch 18/20 - Batch 190/435 - Loss: 0.1328, Acc: 0.9566
#   Epoch 18/20 - Batch 190/435 - Loss: 0.1328, Acc: 0.9566
#   Epoch 18/20 - Batch 200/435 - Loss: 0.1341, Acc: 0.9558
#   Epoch 18/20 - Batch 200/435 - Loss: 0.1341, Acc: 0.9558
#   Epoch 18/20 - Batch 210/435 - Loss: 0.1338, Acc: 0.9553
#   Epoch 18/20 - Batch 210/435 - Loss: 0.1338, Acc: 0.9553
#   Epoch 18/20 - Batch 220/435 - Loss: 0.1332, Acc: 0.9556
#   Epoch 18/20 - Batch 220/435 - Loss: 0.1332, Acc: 0.9556
#   Epoch 18/20 - Batch 230/435 - Loss: 0.1332, Acc: 0.9551
#   Epoch 18/20 - Batch 230/435 - Loss: 0.1332, Acc: 0.9551
#   Epoch 18/20 - Batch 240/435 - Loss: 0.1327, Acc: 0.9555
#   Epoch 18/20 - Batch 240/435 - Loss: 0.1327, Acc: 0.9555
#   Epoch 18/20 - Batch 250/435 - Loss: 0.1336, Acc: 0.9549
#   Epoch 18/20 - Batch 250/435 - Loss: 0.1336, Acc: 0.9549
#   Epoch 18/20 - Batch 260/435 - Loss: 0.1348, Acc: 0.9550
#   Epoch 18/20 - Batch 260/435 - Loss: 0.1348, Acc: 0.9550
#   Epoch 18/20 - Batch 270/435 - Loss: 0.1351, Acc: 0.9551
#   Epoch 18/20 - Batch 270/435 - Loss: 0.1351, Acc: 0.9551
#   Epoch 18/20 - Batch 280/435 - Loss: 0.1357, Acc: 0.9550
#   Epoch 18/20 - Batch 280/435 - Loss: 0.1357, Acc: 0.9550
#   Epoch 18/20 - Batch 290/435 - Loss: 0.1356, Acc: 0.9547
#   Epoch 18/20 - Batch 290/435 - Loss: 0.1356, Acc: 0.9547
#   Epoch 18/20 - Batch 300/435 - Loss: 0.1357, Acc: 0.9548
#   Epoch 18/20 - Batch 300/435 - Loss: 0.1357, Acc: 0.9548
#   Epoch 18/20 - Batch 310/435 - Loss: 0.1351, Acc: 0.9549
#   Epoch 18/20 - Batch 310/435 - Loss: 0.1351, Acc: 0.9549
#   Epoch 18/20 - Batch 320/435 - Loss: 0.1347, Acc: 0.9554
#   Epoch 18/20 - Batch 320/435 - Loss: 0.1347, Acc: 0.9554
#   Epoch 18/20 - Batch 330/435 - Loss: 0.1350, Acc: 0.9553
#   Epoch 18/20 - Batch 330/435 - Loss: 0.1350, Acc: 0.9553
#   Epoch 18/20 - Batch 340/435 - Loss: 0.1343, Acc: 0.9553
#   Epoch 18/20 - Batch 340/435 - Loss: 0.1343, Acc: 0.9553
#   Epoch 18/20 - Batch 350/435 - Loss: 0.1352, Acc: 0.9547
#   Epoch 18/20 - Batch 350/435 - Loss: 0.1352, Acc: 0.9547
#   Epoch 18/20 - Batch 360/435 - Loss: 0.1352, Acc: 0.9546
#   Epoch 18/20 - Batch 360/435 - Loss: 0.1352, Acc: 0.9546
#   Epoch 18/20 - Batch 370/435 - Loss: 0.1356, Acc: 0.9544
#   Epoch 18/20 - Batch 370/435 - Loss: 0.1356, Acc: 0.9544
#   Epoch 18/20 - Batch 380/435 - Loss: 0.1352, Acc: 0.9547
#   Epoch 18/20 - Batch 380/435 - Loss: 0.1352, Acc: 0.9547
#   Epoch 18/20 - Batch 390/435 - Loss: 0.1349, Acc: 0.9548
#   Epoch 18/20 - Batch 390/435 - Loss: 0.1349, Acc: 0.9548
#   Epoch 18/20 - Batch 400/435 - Loss: 0.1366, Acc: 0.9542
#   Epoch 18/20 - Batch 400/435 - Loss: 0.1366, Acc: 0.9542
#   Epoch 18/20 - Batch 410/435 - Loss: 0.1364, Acc: 0.9545
#   Epoch 18/20 - Batch 410/435 - Loss: 0.1364, Acc: 0.9545
#   Epoch 18/20 - Batch 420/435 - Loss: 0.1371, Acc: 0.9543
#   Epoch 18/20 - Batch 420/435 - Loss: 0.1371, Acc: 0.9543
#   Epoch 18/20 - Batch 430/435 - Loss: 0.1376, Acc: 0.9539
#   Epoch 18/20 - Batch 430/435 - Loss: 0.1376, Acc: 0.9539
# Epoch 18/20 (133.9s) - Train: Loss=0.1380, Acc=0.9537 | Val: Loss=1.0138, Acc=0.7807 | LR=1.00e-04
# ⚠️ Early stopping counter: 3/5
# Epoch 18/20 (133.9s) - Train: Loss=0.1380, Acc=0.9537 | Val: Loss=1.0138, Acc=0.7807 | LR=1.00e-04
# ⚠️ Early stopping counter: 3/5
#   Epoch 19/20 - Batch 10/435 - Loss: 0.1084, Acc: 0.9716
#   Epoch 19/20 - Batch 10/435 - Loss: 0.1084, Acc: 0.9716
#   Epoch 19/20 - Batch 20/435 - Loss: 0.1043, Acc: 0.9747
#   Epoch 19/20 - Batch 20/435 - Loss: 0.1043, Acc: 0.9747
#   Epoch 19/20 - Batch 30/435 - Loss: 0.1093, Acc: 0.9718
#   Epoch 19/20 - Batch 30/435 - Loss: 0.1093, Acc: 0.9718
#   Epoch 19/20 - Batch 40/435 - Loss: 0.1084, Acc: 0.9710
#   Epoch 19/20 - Batch 40/435 - Loss: 0.1084, Acc: 0.9710
#   Epoch 19/20 - Batch 50/435 - Loss: 0.1076, Acc: 0.9706
#   Epoch 19/20 - Batch 50/435 - Loss: 0.1076, Acc: 0.9706
#   Epoch 19/20 - Batch 60/435 - Loss: 0.1124, Acc: 0.9698
#   Epoch 19/20 - Batch 60/435 - Loss: 0.1124, Acc: 0.9698
#   Epoch 19/20 - Batch 70/435 - Loss: 0.1108, Acc: 0.9688
#   Epoch 19/20 - Batch 70/435 - Loss: 0.1108, Acc: 0.9688
#   Epoch 19/20 - Batch 80/435 - Loss: 0.1116, Acc: 0.9680
#   Epoch 19/20 - Batch 80/435 - Loss: 0.1116, Acc: 0.9680
#   Epoch 19/20 - Batch 90/435 - Loss: 0.1214, Acc: 0.9653
#   Epoch 19/20 - Batch 90/435 - Loss: 0.1214, Acc: 0.9653
#   Epoch 19/20 - Batch 100/435 - Loss: 0.1205, Acc: 0.9653
#   Epoch 19/20 - Batch 100/435 - Loss: 0.1205, Acc: 0.9653
#   Epoch 19/20 - Batch 110/435 - Loss: 0.1238, Acc: 0.9634
#   Epoch 19/20 - Batch 110/435 - Loss: 0.1238, Acc: 0.9634
#   Epoch 19/20 - Batch 120/435 - Loss: 0.1240, Acc: 0.9633
#   Epoch 19/20 - Batch 120/435 - Loss: 0.1240, Acc: 0.9633
#   Epoch 19/20 - Batch 130/435 - Loss: 0.1239, Acc: 0.9628
#   Epoch 19/20 - Batch 130/435 - Loss: 0.1239, Acc: 0.9628
#   Epoch 19/20 - Batch 140/435 - Loss: 0.1242, Acc: 0.9628
#   Epoch 19/20 - Batch 140/435 - Loss: 0.1242, Acc: 0.9628
#   Epoch 19/20 - Batch 150/435 - Loss: 0.1228, Acc: 0.9630
#   Epoch 19/20 - Batch 150/435 - Loss: 0.1228, Acc: 0.9630
#   Epoch 19/20 - Batch 160/435 - Loss: 0.1224, Acc: 0.9629
#   Epoch 19/20 - Batch 160/435 - Loss: 0.1224, Acc: 0.9629
#   Epoch 19/20 - Batch 170/435 - Loss: 0.1234, Acc: 0.9631
#   Epoch 19/20 - Batch 170/435 - Loss: 0.1234, Acc: 0.9631
#   Epoch 19/20 - Batch 180/435 - Loss: 0.1237, Acc: 0.9629
#   Epoch 19/20 - Batch 180/435 - Loss: 0.1237, Acc: 0.9629
#   Epoch 19/20 - Batch 190/435 - Loss: 0.1237, Acc: 0.9629
#   Epoch 19/20 - Batch 190/435 - Loss: 0.1237, Acc: 0.9629
#   Epoch 19/20 - Batch 200/435 - Loss: 0.1251, Acc: 0.9619
#   Epoch 19/20 - Batch 200/435 - Loss: 0.1251, Acc: 0.9619
#   Epoch 19/20 - Batch 210/435 - Loss: 0.1256, Acc: 0.9616
#   Epoch 19/20 - Batch 210/435 - Loss: 0.1256, Acc: 0.9616
#   Epoch 19/20 - Batch 220/435 - Loss: 0.1282, Acc: 0.9610
#   Epoch 19/20 - Batch 220/435 - Loss: 0.1282, Acc: 0.9610
#   Epoch 19/20 - Batch 230/435 - Loss: 0.1288, Acc: 0.9602
#   Epoch 19/20 - Batch 230/435 - Loss: 0.1288, Acc: 0.9602
#   Epoch 19/20 - Batch 240/435 - Loss: 0.1294, Acc: 0.9597
#   Epoch 19/20 - Batch 240/435 - Loss: 0.1294, Acc: 0.9597
#   Epoch 19/20 - Batch 250/435 - Loss: 0.1284, Acc: 0.9598
#   Epoch 19/20 - Batch 250/435 - Loss: 0.1284, Acc: 0.9598
#   Epoch 19/20 - Batch 260/435 - Loss: 0.1277, Acc: 0.9595
#   Epoch 19/20 - Batch 260/435 - Loss: 0.1277, Acc: 0.9595
#   Epoch 19/20 - Batch 270/435 - Loss: 0.1290, Acc: 0.9591
#   Epoch 19/20 - Batch 270/435 - Loss: 0.1290, Acc: 0.9591
#   Epoch 19/20 - Batch 280/435 - Loss: 0.1302, Acc: 0.9585
#   Epoch 19/20 - Batch 280/435 - Loss: 0.1302, Acc: 0.9585
#   Epoch 19/20 - Batch 290/435 - Loss: 0.1294, Acc: 0.9588
#   Epoch 19/20 - Batch 290/435 - Loss: 0.1294, Acc: 0.9588
#   Epoch 19/20 - Batch 300/435 - Loss: 0.1289, Acc: 0.9592
#   Epoch 19/20 - Batch 300/435 - Loss: 0.1289, Acc: 0.9592
#   Epoch 19/20 - Batch 310/435 - Loss: 0.1283, Acc: 0.9592
#   Epoch 19/20 - Batch 310/435 - Loss: 0.1283, Acc: 0.9592
#   Epoch 19/20 - Batch 320/435 - Loss: 0.1295, Acc: 0.9587
#   Epoch 19/20 - Batch 320/435 - Loss: 0.1295, Acc: 0.9587
#   Epoch 19/20 - Batch 330/435 - Loss: 0.1277, Acc: 0.9593
#   Epoch 19/20 - Batch 330/435 - Loss: 0.1277, Acc: 0.9593
#   Epoch 19/20 - Batch 340/435 - Loss: 0.1300, Acc: 0.9585
#   Epoch 19/20 - Batch 340/435 - Loss: 0.1300, Acc: 0.9585
#   Epoch 19/20 - Batch 350/435 - Loss: 0.1296, Acc: 0.9582
#   Epoch 19/20 - Batch 350/435 - Loss: 0.1296, Acc: 0.9582
#   Epoch 19/20 - Batch 360/435 - Loss: 0.1282, Acc: 0.9588
#   Epoch 19/20 - Batch 360/435 - Loss: 0.1282, Acc: 0.9588
#   Epoch 19/20 - Batch 370/435 - Loss: 0.1286, Acc: 0.9585
#   Epoch 19/20 - Batch 370/435 - Loss: 0.1286, Acc: 0.9585
#   Epoch 19/20 - Batch 380/435 - Loss: 0.1292, Acc: 0.9583
#   Epoch 19/20 - Batch 380/435 - Loss: 0.1292, Acc: 0.9583
#   Epoch 19/20 - Batch 390/435 - Loss: 0.1295, Acc: 0.9582
#   Epoch 19/20 - Batch 390/435 - Loss: 0.1295, Acc: 0.9582
#   Epoch 19/20 - Batch 400/435 - Loss: 0.1304, Acc: 0.9579
#   Epoch 19/20 - Batch 400/435 - Loss: 0.1304, Acc: 0.9579
#   Epoch 19/20 - Batch 410/435 - Loss: 0.1310, Acc: 0.9579
#   Epoch 19/20 - Batch 410/435 - Loss: 0.1310, Acc: 0.9579
#   Epoch 19/20 - Batch 420/435 - Loss: 0.1304, Acc: 0.9584
#   Epoch 19/20 - Batch 420/435 - Loss: 0.1304, Acc: 0.9584
#   Epoch 19/20 - Batch 430/435 - Loss: 0.1309, Acc: 0.9579
#   Epoch 19/20 - Batch 430/435 - Loss: 0.1309, Acc: 0.9579
# Epoch 19/20 (133.7s) - Train: Loss=0.1312, Acc=0.9578 | Val: Loss=1.0157, Acc=0.7872 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7872
# Epoch 19/20 (133.7s) - Train: Loss=0.1312, Acc=0.9578 | Val: Loss=1.0157, Acc=0.7872 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7872
#   Epoch 20/20 - Batch 10/435 - Loss: 0.0880, Acc: 0.9744
#   Epoch 20/20 - Batch 10/435 - Loss: 0.0880, Acc: 0.9744
#   Epoch 20/20 - Batch 20/435 - Loss: 0.0906, Acc: 0.9673
#   Epoch 20/20 - Batch 20/435 - Loss: 0.0906, Acc: 0.9673
#   Epoch 20/20 - Batch 30/435 - Loss: 0.1000, Acc: 0.9637
#   Epoch 20/20 - Batch 30/435 - Loss: 0.1000, Acc: 0.9637
#   Epoch 20/20 - Batch 40/435 - Loss: 0.1233, Acc: 0.9596
#   Epoch 20/20 - Batch 40/435 - Loss: 0.1233, Acc: 0.9596
#   Epoch 20/20 - Batch 50/435 - Loss: 0.1187, Acc: 0.9608
#   Epoch 20/20 - Batch 50/435 - Loss: 0.1187, Acc: 0.9608
#   Epoch 20/20 - Batch 60/435 - Loss: 0.1180, Acc: 0.9585
#   Epoch 20/20 - Batch 60/435 - Loss: 0.1180, Acc: 0.9585
#   Epoch 20/20 - Batch 70/435 - Loss: 0.1154, Acc: 0.9591
#   Epoch 20/20 - Batch 70/435 - Loss: 0.1154, Acc: 0.9591
#   Epoch 20/20 - Batch 80/435 - Loss: 0.1133, Acc: 0.9603
#   Epoch 20/20 - Batch 80/435 - Loss: 0.1133, Acc: 0.9603
#   Epoch 20/20 - Batch 90/435 - Loss: 0.1114, Acc: 0.9615
#   Epoch 20/20 - Batch 90/435 - Loss: 0.1114, Acc: 0.9615
#   Epoch 20/20 - Batch 100/435 - Loss: 0.1101, Acc: 0.9623
#   Epoch 20/20 - Batch 100/435 - Loss: 0.1101, Acc: 0.9623
#   Epoch 20/20 - Batch 110/435 - Loss: 0.1101, Acc: 0.9606
#   Epoch 20/20 - Batch 110/435 - Loss: 0.1101, Acc: 0.9606
#   Epoch 20/20 - Batch 120/435 - Loss: 0.1093, Acc: 0.9615
#   Epoch 20/20 - Batch 120/435 - Loss: 0.1093, Acc: 0.9615
#   Epoch 20/20 - Batch 130/435 - Loss: 0.1112, Acc: 0.9606
#   Epoch 20/20 - Batch 130/435 - Loss: 0.1112, Acc: 0.9606
#   Epoch 20/20 - Batch 140/435 - Loss: 0.1105, Acc: 0.9621
#   Epoch 20/20 - Batch 140/435 - Loss: 0.1105, Acc: 0.9621
#   Epoch 20/20 - Batch 150/435 - Loss: 0.1102, Acc: 0.9627
#   Epoch 20/20 - Batch 150/435 - Loss: 0.1102, Acc: 0.9627
#   Epoch 20/20 - Batch 160/435 - Loss: 0.1097, Acc: 0.9635
#   Epoch 20/20 - Batch 160/435 - Loss: 0.1097, Acc: 0.9635
#   Epoch 20/20 - Batch 170/435 - Loss: 0.1109, Acc: 0.9636
#   Epoch 20/20 - Batch 170/435 - Loss: 0.1109, Acc: 0.9636
#   Epoch 20/20 - Batch 180/435 - Loss: 0.1116, Acc: 0.9639
#   Epoch 20/20 - Batch 180/435 - Loss: 0.1116, Acc: 0.9639
#   Epoch 20/20 - Batch 190/435 - Loss: 0.1100, Acc: 0.9647
#   Epoch 20/20 - Batch 190/435 - Loss: 0.1100, Acc: 0.9647
#   Epoch 20/20 - Batch 200/435 - Loss: 0.1136, Acc: 0.9636
#   Epoch 20/20 - Batch 200/435 - Loss: 0.1136, Acc: 0.9636
#   Epoch 20/20 - Batch 210/435 - Loss: 0.1129, Acc: 0.9639
#   Epoch 20/20 - Batch 210/435 - Loss: 0.1129, Acc: 0.9639
#   Epoch 20/20 - Batch 220/435 - Loss: 0.1132, Acc: 0.9637
#   Epoch 20/20 - Batch 220/435 - Loss: 0.1132, Acc: 0.9637
#   Epoch 20/20 - Batch 230/435 - Loss: 0.1122, Acc: 0.9639
#   Epoch 20/20 - Batch 230/435 - Loss: 0.1122, Acc: 0.9639
#   Epoch 20/20 - Batch 240/435 - Loss: 0.1131, Acc: 0.9637
#   Epoch 20/20 - Batch 240/435 - Loss: 0.1131, Acc: 0.9637
#   Epoch 20/20 - Batch 250/435 - Loss: 0.1136, Acc: 0.9636
#   Epoch 20/20 - Batch 250/435 - Loss: 0.1136, Acc: 0.9636
#   Epoch 20/20 - Batch 260/435 - Loss: 0.1150, Acc: 0.9632
#   Epoch 20/20 - Batch 260/435 - Loss: 0.1150, Acc: 0.9632
#   Epoch 20/20 - Batch 270/435 - Loss: 0.1146, Acc: 0.9637
#   Epoch 20/20 - Batch 270/435 - Loss: 0.1146, Acc: 0.9637
#   Epoch 20/20 - Batch 280/435 - Loss: 0.1151, Acc: 0.9634
#   Epoch 20/20 - Batch 280/435 - Loss: 0.1151, Acc: 0.9634
#   Epoch 20/20 - Batch 290/435 - Loss: 0.1143, Acc: 0.9636
#   Epoch 20/20 - Batch 290/435 - Loss: 0.1143, Acc: 0.9636
#   Epoch 20/20 - Batch 300/435 - Loss: 0.1146, Acc: 0.9636
#   Epoch 20/20 - Batch 300/435 - Loss: 0.1146, Acc: 0.9636
#   Epoch 20/20 - Batch 310/435 - Loss: 0.1149, Acc: 0.9633
#   Epoch 20/20 - Batch 310/435 - Loss: 0.1149, Acc: 0.9633
#   Epoch 20/20 - Batch 320/435 - Loss: 0.1148, Acc: 0.9636
#   Epoch 20/20 - Batch 320/435 - Loss: 0.1148, Acc: 0.9636
#   Epoch 20/20 - Batch 330/435 - Loss: 0.1143, Acc: 0.9637
#   Epoch 20/20 - Batch 330/435 - Loss: 0.1143, Acc: 0.9637
#   Epoch 20/20 - Batch 340/435 - Loss: 0.1155, Acc: 0.9631
#   Epoch 20/20 - Batch 340/435 - Loss: 0.1155, Acc: 0.9631
#   Epoch 20/20 - Batch 350/435 - Loss: 0.1173, Acc: 0.9626
#   Epoch 20/20 - Batch 350/435 - Loss: 0.1173, Acc: 0.9626
#   Epoch 20/20 - Batch 360/435 - Loss: 0.1174, Acc: 0.9628
#   Epoch 20/20 - Batch 360/435 - Loss: 0.1174, Acc: 0.9628
#   Epoch 20/20 - Batch 370/435 - Loss: 0.1172, Acc: 0.9629
#   Epoch 20/20 - Batch 370/435 - Loss: 0.1172, Acc: 0.9629
#   Epoch 20/20 - Batch 380/435 - Loss: 0.1176, Acc: 0.9627
#   Epoch 20/20 - Batch 380/435 - Loss: 0.1176, Acc: 0.9627
#   Epoch 20/20 - Batch 390/435 - Loss: 0.1187, Acc: 0.9620
#   Epoch 20/20 - Batch 390/435 - Loss: 0.1187, Acc: 0.9620
#   Epoch 20/20 - Batch 400/435 - Loss: 0.1179, Acc: 0.9620
#   Epoch 20/20 - Batch 400/435 - Loss: 0.1179, Acc: 0.9620
#   Epoch 20/20 - Batch 410/435 - Loss: 0.1189, Acc: 0.9620
#   Epoch 20/20 - Batch 410/435 - Loss: 0.1189, Acc: 0.9620
#   Epoch 20/20 - Batch 420/435 - Loss: 0.1178, Acc: 0.9624
#   Epoch 20/20 - Batch 420/435 - Loss: 0.1178, Acc: 0.9624
#   Epoch 20/20 - Batch 430/435 - Loss: 0.1186, Acc: 0.9619
#   Epoch 20/20 - Batch 430/435 - Loss: 0.1186, Acc: 0.9619
# Epoch 20/20 (134.6s) - Train: Loss=0.1185, Acc=0.9620 | Val: Loss=0.9929, Acc=0.7898 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7898
# 💾 주기적 체크포인트 저장: epoch_020
#
# 학습 완료!
# 총 소요 시간: 45.6분
# 최고 검증 정확도: 0.7898
# Epoch 20/20 (134.6s) - Train: Loss=0.1185, Acc=0.9620 | Val: Loss=0.9929, Acc=0.7898 | LR=1.00e-04
# 📌 새로운 베스트 모델 저장! Val Acc: 0.7898
# 💾 주기적 체크포인트 저장: epoch_020
#
# 학습 완료!
# 총 소요 시간: 45.6분
# 최고 검증 정확도: 0.7898
# ✅ 베스트 모델 로드 완료! (에폭 20, Val Acc: 0.7898)
# ✅ 베스트 모델 로드 완료! (에폭 20, Val Acc: 0.7898)

# %%
# 모델 저장/로드 유틸리티 함수들
import json
import pickle

def save_complete_model(model, save_dir, model_name, epoch, metrics, config):
    """
    완전한 모델 정보를 저장하는 함수
    """
    # 1. 모델 상태 저장
    model_path = os.path.join(save_dir, f'{model_name}_epoch_{epoch:03d}.pth')
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'metrics': metrics,
        'config': config,
        'timestamp': datetime.now().isoformat(),
    }, model_path)
    
    # 2. 설정 정보 JSON으로 저장
    config_path = os.path.join(save_dir, f'{model_name}_config.json')
    with open(config_path, 'w', encoding='utf-8') as f:
        json.dump(config, f, indent=2, ensure_ascii=False)
    
    # 3. 메트릭 정보 저장
    metrics_path = os.path.join(save_dir, f'{model_name}_metrics.json')
    with open(metrics_path, 'w', encoding='utf-8') as f:
        json.dump(metrics, f, indent=2, ensure_ascii=False)
    
    return model_path

def load_complete_model(model, checkpoint_path):
    """
    완전한 모델 정보를 로드하는 함수
    """
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    
    return {
        'epoch': checkpoint['epoch'],
        'metrics': checkpoint['metrics'],
        'config': checkpoint['config'],
        'timestamp': checkpoint.get('timestamp', 'Unknown'),
    }

def create_model_summary(model, save_path):
    """
    모델 요약 정보를 생성하고 저장
    """
    summary_info = {
        'model_type': type(model).__name__,
        'total_params': sum(p.numel() for p in model.parameters()),
        'trainable_params': sum(p.numel() for p in model.parameters() if p.requires_grad),
        'model_size_mb': sum(p.numel() * p.element_size() for p in model.parameters()) / (1024 * 1024),
        'layers': [],
    }
    
    # 레이어 정보 수집
    for name, module in model.named_modules():
        if len(list(module.children())) == 0:  # leaf module만
            summary_info['layers'].append({
                'name': name,
                'type': type(module).__name__,
                'parameters': sum(p.numel() for p in module.parameters()),
            })
    
    with open(save_path, 'w', encoding='utf-8') as f:
        json.dump(summary_info, f, indent=2, ensure_ascii=False)
    
    return summary_info

# 모델 요약 정보 저장
summary_path = os.path.join(results_dir, 'model_summary.json')
model_summary = create_model_summary(model, summary_path)

print("=== 모델 요약 ===")
print(f"총 파라미터: {model_summary['total_params']:,}")
print(f"학습 가능한 파라미터: {model_summary['trainable_params']:,}")
print(f"모델 크기: {model_summary['model_size_mb']:.2f} MB")
print(f"요약 정보 저장: {summary_path}")

# 자동 백업 설정
def setup_auto_backup(results_dir, max_backups=5):
    """
    이전 결과들을 자동으로 백업하는 함수
    """
    backup_dir = os.path.join(results_dir, 'backups')
    os.makedirs(backup_dir, exist_ok=True)
    
    # 기존 백업 파일들 확인
    backup_files = [f for f in os.listdir(backup_dir) if f.startswith('backup_')]
    if len(backup_files) >= max_backups:
        # 가장 오래된 백업 삭제
        backup_files.sort()
        oldest_backup = os.path.join(backup_dir, backup_files[0])
        if os.path.isdir(oldest_backup):
            import shutil
            shutil.rmtree(oldest_backup)
    
    return backup_dir

backup_dir = setup_auto_backup(results_dir)
print(f"백업 디렉토리 설정: {backup_dir}")
# Out:
# === 모델 요약 ===
# 총 파라미터: 4,035,730
# 학습 가능한 파라미터: 4,035,730
# 모델 크기: 15.40 MB
# 요약 정보 저장: results\20251021_145847\model_summary.json
# 백업 디렉토리 설정: results\20251021_145847\backups

# %%
# 실시간 학습 곡선 시각화 및 모니터링
import matplotlib.pyplot as plt
import pandas as pd

def plot_training_curves(train_losses, val_losses, train_accs, val_accs, save_path=None):
    """
    학습 곡선을 시각화하는 함수
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs = range(1, len(train_losses) + 1)
    
    # Loss 곡선
    ax1.plot(epochs, train_losses, 'b-', label='Training Loss', linewidth=2)
    ax1.plot(epochs, val_losses, 'r-', label='Validation Loss', linewidth=2)
    ax1.set_title('Training and Validation Loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Accuracy 곡선
    ax2.plot(epochs, train_accs, 'b-', label='Training Accuracy', linewidth=2)
    ax2.plot(epochs, val_accs, 'r-', label='Validation Accuracy', linewidth=2)
    ax2.set_title('Training and Validation Accuracy')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"학습 곡선 저장: {save_path}")
    
    plt.show()

def monitor_training_progress(metrics_log_path):
    """
    학습 진행상황을 모니터링하는 함수
    """
    if os.path.exists(metrics_log_path):
        df = pd.read_csv(metrics_log_path)
        
        print("=== 학습 진행 상황 ===")
        if len(df) > 0:
            latest = df.iloc[-1]
            print(f"현재 에폭: {int(latest['epoch'])}")
            print(f"최신 Train Loss: {latest['train_loss']:.4f}")
            print(f"최신 Train Acc: {latest['train_acc']:.4f}")
            print(f"최신 Val Loss: {latest['val_loss']:.4f}")
            print(f"최신 Val Acc: {latest['val_acc']:.4f}")
            print(f"현재 Learning Rate: {latest['learning_rate']:.2e}")
            
            # 최고 성능 확인
            best_epoch = df.loc[df['val_acc'].idxmax()]
            print(f"\n=== 최고 성능 ===")
            print(f"최고 Val Acc: {best_epoch['val_acc']:.4f} (에폭 {int(best_epoch['epoch'])})")
            
            return df
    
    return None

def save_training_summary(results_dir, train_losses, val_losses, train_accs, val_accs, best_val_acc, total_epochs):
    """
    학습 완료 후 전체 요약을 저장하는 함수
    """
    summary = {
        'training_completed': True,
        'total_epochs': total_epochs,
        'best_validation_accuracy': float(best_val_acc),
        'final_train_loss': float(train_losses[-1]) if train_losses else 0,
        'final_val_loss': float(val_losses[-1]) if val_losses else 0,
        'final_train_acc': float(train_accs[-1]) if train_accs else 0,
        'final_val_acc': float(val_accs[-1]) if val_accs else 0,
        'training_history': {
            'train_losses': [float(x) for x in train_losses],
            'val_losses': [float(x) for x in val_losses],
            'train_accs': [float(x) for x in train_accs],
            'val_accs': [float(x) for x in val_accs],
        },
        'timestamp': datetime.now().isoformat(),
    }
    
    summary_path = os.path.join(results_dir, 'training_summary.json')
    with open(summary_path, 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2, ensure_ascii=False)
    
    print(f"학습 요약 저장: {summary_path}")
    return summary_path

print("📊 학습 모니터링 함수들이 준비되었습니다.")
print("- plot_training_curves(): 학습 곡선 시각화")
print("- monitor_training_progress(): 실시간 진행상황 확인")
print("- save_training_summary(): 학습 완료 후 요약 저장")
# Out:
# 📊 학습 모니터링 함수들이 준비되었습니다.
# - plot_training_curves(): 학습 곡선 시각화
# - monitor_training_progress(): 실시간 진행상황 확인
# - save_training_summary(): 학습 완료 후 요약 저장

# %%
# 7. 개선된 평가 및 리포트 + 완전한 결과 저장
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support
import numpy as np
import json
import pandas as pd

# %%
# 학습 곡선 시각화 및 최종 요약 저장
if len(train_losses) > 0:  # 학습이 실제로 실행된 경우에만
    # 학습 곡선 플롯
    curves_path = os.path.join(results_dir, 'training_curves.png')
    plot_training_curves(train_losses, val_losses, train_accs, val_accs, save_path=curves_path)
    
    # 최종 학습 요약 저장
    summary_path = save_training_summary(results_dir, train_losses, val_losses, train_accs, val_accs, best_val_acc, len(train_losses))
    
    # 진행상황 모니터링 (CSV가 존재하는 경우)
    metrics_log_path = os.path.join(results_dir, 'metrics_log.csv')
    df_metrics = monitor_training_progress(metrics_log_path)
    
    print(f"\n📊 모든 결과가 '{results_dir}' 폴더에 저장되었습니다!")
    print("\n저장된 파일들:")
    print("📈 training_curves.png - 학습 곡선 그래프")
    print("📋 training_summary.json - 전체 학습 요약")
    print("📊 metrics_log.csv - 에폭별 상세 메트릭")
    print("🏆 best_efficientnet.pth - 최고 성능 모델")
    print("💾 latest_efficientnet.pth - 최신 모델")
    print("📁 periodic_checkpoints/ - 주기적 체크포인트들")
    print("📄 train_log.txt - 학습 로그")
    print("🔍 evaluation_results.json - 상세 평가 결과")
    print("📝 classification_report.txt - 분류 리포트")
    print("🎯 predictions_detailed.csv - 예측 상세 결과")
    print("⚠️ misclassified_analysis.csv - 오분류 분석")
else:
    print("⚠️ 학습이 아직 실행되지 않았습니다. 먼저 학습을 실행해주세요.")
# Out:
# 학습 곡선 저장: results\20251021_145847\training_curves.png
# 학습 요약 저장: results\20251021_145847\training_summary.json
# === 학습 진행 상황 ===
# 현재 에폭: 20
# 최신 Train Loss: 0.1185
# 최신 Train Acc: 0.9620
# 최신 Val Loss: 0.9929
# 최신 Val Acc: 0.7898
# 현재 Learning Rate: 1.00e-04
#
# === 최고 성능 ===
# 최고 Val Acc: 0.7898 (에폭 20)
#
# 📊 모든 결과가 'results\20251021_145847' 폴더에 저장되었습니다!
#
# 저장된 파일들:
# 📈 training_curves.png - 학습 곡선 그래프
# 📋 training_summary.json - 전체 학습 요약
# 📊 metrics_log.csv - 에폭별 상세 메트릭
# 🏆 best_efficientnet.pth - 최고 성능 모델
# 💾 latest_efficientnet.pth - 최신 모델
# 📁 periodic_checkpoints/ - 주기적 체크포인트들
# 📄 train_log.txt - 학습 로그
# 🔍 evaluation_results.json - 상세 평가 결과
# 📝 classification_report.txt - 분류 리포트
# 🎯 predictions_detailed.csv - 예측 상세 결과
# ⚠️ misclassified_analysis.csv - 오분류 분석

# %%
# 8. 혼동행렬 시각화 + 이미지 저장
def plot_confusion_matrix_large(y_true, y_pred, class_names, figsize=(15, 12), fontsize=12, save_path=None):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=figsize)
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=class_names, yticklabels=class_names, annot_kws={'size': fontsize})
    plt.xlabel('Predicted Label', fontsize=fontsize + 2)
    plt.ylabel('True Label', fontsize=fontsize + 2)
    plt.title('Confusion Matrix', fontsize=fontsize + 4)
    plt.xticks(rotation=45, ha='right', fontsize=fontsize)
    plt.yticks(rotation=0, fontsize=fontsize)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
    plt.show()

cm_path = os.path.join(results_dir, 'confusion_matrix.png')
plot_confusion_matrix_large(all_labels, all_preds, class_names, figsize=(18, 15), fontsize=14, save_path=cm_path)
